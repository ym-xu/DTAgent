# %%
# %cd /Users/ymxu/Workspace/MuDocU/DTAgent
# Out:
# /Users/ymxu/Workspace/MuDocU/DTAgent

# %% [markdown]
# # Test Planner (Strict)

# %%
import os, sys, pathlib
def add_repo_root(marker='src'):
    p = pathlib.Path.cwd()
    while p != p.parent:
        if (p/marker).exists():
            sys.path.insert(0, str(p))
            print('Added repo root to sys.path:', p)
            return True
        p = p.parent
    return False
ok = add_repo_root('src')
assert ok, '未找到包含 src/ 的仓库根目录，请手工 %cd 到仓库根'
# Out:
# Added repo root to sys.path: /Users/ymxu/Workspace/MuDocU/DTAgent

# %%
import numpy as np
from src.agents.retriever_impl import JsonlRetriever
from src.agents.planner import PlannerLLMStrict
from src.index.embed_models import get_embedder
from src.utils.llm_clients import gpt_llm_call, qwen_llm_call
print('Imports OK')
# Out:
# Imports OK

# %%
# 严格配置（请按实验修改）
INDEX_DIR = './../../../data/users/yiming/dtagent/MinerU_25_MMLB/honor_watch_gs_pro/indexes'
EMBED_MODEL = 'BAAI/bge-small-en-v1.5'  
LLM_BACKEND = 'gpt'               
LLM_MODEL = 'gpt-4o' 

assert os.path.isdir(INDEX_DIR), f'indexes 目录不存在: {INDEX_DIR}'
print('INDEX_DIR =', os.path.abspath(INDEX_DIR))

if LLM_BACKEND=='gpt':
    assert os.environ.get('OPENAI_API_KEY'), '缺少 OPENAI_API_KEY'
else:
    assert os.environ.get('DASHSCOPE_API_KEY'), '缺少 DASHSCOPE_API_KEY'
# Out:
# INDEX_DIR = /Users/ymxu/data/users/yiming/dtagent/MinerU_25_MMLB/honor_watch_gs_pro/indexes

# %%
emb = get_embedder(EMBED_MODEL)
def encode_fn(texts):
    X = emb.encode(texts)
    return np.array(X, dtype=np.float32)
R = JsonlRetriever(INDEX_DIR, encode_fn)
print('Retriever ready with', EMBED_MODEL)
# Out:
# Retriever ready with BAAI/bge-small-en-v1.5

# %%
def llm_call(messages, json_mode=True, max_tokens=256, **kw):
    if LLM_BACKEND=='gpt':
        return gpt_llm_call(messages, model=LLM_MODEL, json_mode=json_mode)
    return qwen_llm_call(messages, model=LLM_MODEL, json_mode=json_mode)
planner = PlannerLLMStrict(R, llm_call=llm_call, model_name=LLM_MODEL, retry=2, topk_candidates=8, min_pool_size=10)
print('Planner ready:', LLM_BACKEND, LLM_MODEL)
# Out:
# Planner ready: gpt gpt-4o

# %%
question = "If \"--\" is displayed as the resting heart rate reading, what kind of environment should the user stay in?"
plan = planner.plan(question)
print('Candidates:', len(plan.candidates))
for i,c in enumerate(plan.candidates[:10], 1):
    print(f'  #{i}', c.node_id, c.role, f'score={c.score:.4f}', '| why=', ','.join(c.why[:3]))
print('Steps:', len(plan.steps))
for i,s in enumerate(plan.steps, 1):
    print(f'  - [{i}]', s.op, 'node=', s.node, 'expect=', s.expect)
# Out:
# Candidates: 10
#   #1 sec_526 section score=0.2242 | why= dense@37,dense@37,bm25@12
#   #2 sec_474 section score=0.2135 | why= dense@14,dense@14,unit_hit
#   #3 sec_580 section score=0.2116 | why= dense@26,dense@26,unit_hit
#   #4 sec_586 section score=0.2112 | why= dense@29,dense@29,unit_hit
#   #5 sec_230 section score=0.2096 | why= dense@44,dense@44,unit_hit
#   #6 sec_148 section score=0.2085 | why= dense@57,dense@57,unit_hit
#   #7 sec_271 section score=0.2085 | why= dense@58,dense@58,unit_hit
#   #8 sec_152 section score=0.2076 | why= dense@71,dense@71,unit_hit
#   #9 sec_181 section score=0.2075 | why= dense@73,dense@73,unit_hit
#   #10 sec_83 section score=0.2075 | why= dense@74,dense@74,unit_hit
# Steps: 1
#   - [1] SCAN_PARAS node= sec_526 expect= Find information about the environment when resting heart rate is "--".

# %%
question = "How many reasoning steps are involved in the figure 1 in the paper?"
plan = planner.plan(question)
print('Candidates:', len(plan.candidates))
for i,c in enumerate(plan.candidates[:10], 1):
    print(f'  #{i}', c.node_id, c.role, f'score={c.score:.4f}', '| why=', ','.join(c.why[:3]))
print('Steps:', len(plan.steps))
for i,s in enumerate(plan.steps, 1):
    print(f'  - [{i}]', s.op, 'node=', s.node, 'expect=', s.expect)
# Out:
# ---------------------------------------------------------------------------
# PlannerError                              Traceback (most recent call last)
# Cell In[16], line 2
#       1 question = "How many reasoning steps are involved in the figure 1 in the paper?"
# ----> 2 plan = planner.plan(question)
#       3 print('Candidates:', len(plan.candidates))
#       4 for i,c in enumerate(plan.candidates[:10], 1):
#
# File ~/Workspace/MuDocU/DTAgent/src/agents/planner.py:247, in PlannerLLMStrict.plan(self, question, visited)
#     245 visited = visited or []
#     246 # H1: Intent v2（带 roles_seed）
# --> 247 intent = self._call_intent_v2(question)
#     249 # 选择 roles_seed（可能多组，按概率+召回诊断选择；召回弱自动换下一组）
#     250 pool, seed_used, query_used = None, None, None
#
# File ~/Workspace/MuDocU/DTAgent/src/agents/planner.py:336, in PlannerLLMStrict._call_intent_v2(self, question)
#     334     except Exception:
#     335         continue
# --> 336 raise PlannerError("LLM intent_v2 failed")
#
# PlannerError: LLM intent_v2 failed

# %%
question = "How many green and grey rectangles in the first figure of the paper? Please list the numbers in the list format by descending order. e.g., [\"2\",\"1\"]"
plan = planner.plan(question)
print('Candidates:', len(plan.candidates))
for i,c in enumerate(plan.candidates[:10], 1):
    print(f'  #{i}', c.node_id, c.role, f'score={c.score:.4f}', '| why=', ','.join(c.why[:3]))
print('Steps:', len(plan.steps))
for i,s in enumerate(plan.steps, 1):
    print(f'  - [{i}]', s.op, 'node=', s.node, 'expect=', s.expect)
# Out:
# Candidates: 10
#   #1 img_45 image score=0.4313 | why= dense@2,dense@2,bm25@6
#   #2 img_13 image score=0.2313 | why= dense@6,dense@6,bm25@2
#   #3 img_75 image score=0.2313 | why= dense@3,dense@3,bm25@5
#   #4 img_14 image score=0.2300 | why= dense@11,dense@11,bm25@3
#   #5 sec_106 section score=0.2288 | why= dense@7,dense@7,bm25@12
#   #6 img_25 image score=0.2284 | why= dense@18,dense@18,bm25@4
#   #7 sec_125 section score=0.2261 | why= dense@23,dense@23,bm25@11
#   #8 sec_116 section score=0.2250 | why= dense@26,dense@26,bm25@15
#   #9 sec_133 section score=0.2249 | why= dense@36,dense@36,bm25@9
#   #10 sec_36 section score=0.2244 | why= dense@28,dense@28,bm25@17
# Steps: 3
#   - [1] FIND_NODES node= img_13 expect= nodes containing green and grey rectangles
#   - [2] COUNT node= img_13 expect= count of green and grey rectangles
#   - [3] COUNT node= img_25 expect= count of green and grey rectangles

# %%
question = "How many more claims does the Wiki Table datasets have comparing to scientific articles datasets? Please writeh the answer in int format."
plan = planner.plan(question)
print('Candidates:', len(plan.candidates))
for i,c in enumerate(plan.candidates[:10], 1):
    print(f'  #{i}', c.node_id, c.role, f'score={c.score:.4f}', '| why=', ','.join(c.why[:3]))
print('Steps:', len(plan.steps))
for i,s in enumerate(plan.steps, 1):
    print(f'  - [{i}]', s.op, 'node=', s.node, 'expect=', s.expect)
# Out:
# Candidates: 10
#   #1 tab_314 table score=0.6283 | why= dense@4,dense@4,bm25@19
#   #2 tab_307 table score=0.6282 | why= dense@3,dense@3,bm25@21
#   #3 tab_33 table score=0.4328 | why= dense@1,dense@1,bm25@1
#   #4 tab_333 table score=0.4315 | why= dense@2,dense@2,bm25@5
#   #5 tab_352 table score=0.4313 | why= dense@5,dense@5,bm25@3
#   #6 tab_44 table score=0.4302 | why= dense@11,dense@11,bm25@2
#   #7 tab_76 table score=0.4301 | why= dense@9,dense@9,bm25@4
#   #8 tab_123 table score=0.4292 | why= dense@7,dense@7,bm25@10
#   #9 tab_327 table score=0.4285 | why= dense@6,dense@6,bm25@15
#   #10 tab_53 table score=0.4284 | why= dense@12,dense@12,bm25@9
# Steps: 3
#   - [1] FIND_NODES node= tab_314 expect= Node found for Wiki Table dataset
#   - [2] COUNT node= tab_314 expect= Count of claims for Wiki Table dataset
#   - [3] COUNT node= tab_307 expect= Count of claims for scientific articles dataset

# %%
question = "How many USD dollars will the author spend if the annotators finish annotating all of claims of the authors' proposed dataset? Please write the answer in float format."
plan = planner.plan(question)
print('Candidates:', len(plan.candidates))
for i,c in enumerate(plan.candidates[:10], 1):
    print(f'  #{i}', c.node_id, c.role, f'score={c.score:.4f}', '| why=', ','.join(c.why[:3]))
print('Steps:', len(plan.steps))
for i,s in enumerate(plan.steps, 1):
    print(f'  - [{i}]', s.op, 'node=', s.node, 'expect=', s.expect)
# Out:
# Candidates: 10
#   #1 sec_109 section score=0.2306 | why= dense@8,dense@8,bm25@3
#   #2 sec_47 section score=0.2267 | why= dense@18,dense@18,bm25@12
#   #3 sec_36 section score=0.2258 | why= dense@25,dense@25,bm25@11
#   #4 sec_106 section score=0.2161 | why= dense@2,dense@2,unit_hit
#   #5 sec_38 section score=0.2154 | why= dense@5,dense@5,unit_hit
#   #6 sec_0 section score=0.2152 | why= dense@6,dense@6,unit_hit
#   #7 sec_112 section score=0.2149 | why= dense@7,dense@7,unit_hit
#   #8 sec_114 section score=0.2141 | why= dense@11,dense@11,unit_hit
#   #9 sec_125 section score=0.2139 | why= dense@12,dense@12,unit_hit
#   #10 sec_116 section score=0.2123 | why= dense@21,dense@21,unit_hit
# Steps: 3
#   - [1] FIND_NODES node= sec_109 expect= nodes containing cost information in USD
#   - [2] FIND_COL node= sec_109 expect= column index for cost
#   - [3] COUNT node= sec_109 expect= total cost in USD

# %%
doc_path = "./../../../../data/users/yiming/dtagent/MinerU_25_MMLB/f8d3a162ab9507e021d83dd109118b60/doctree.mm.json"

# %%
import json, os
from typing import Any, Dict, List, Tuple, Optional
from collections import defaultdict, Counter

def load_doctree(path: str) -> Dict[str, Any]:
    with open(path, "r", encoding="utf-8") as f:
        root = json.load(f)
    if not (isinstance(root, dict) and root.get("type") == "document"):
        raise ValueError("不是 DocTree 根节点（type=document）")
    return root

# %%
root
# Out:
# {'type': 'document',
#  'doc_id': 'ACTIVISIONBLIZZARD_2019_10K',
#  'meta': {'pages': 198, 'mode': 'doc', 'columns': 1},
#  'toc': [{'title': 'PART I', 'level': 1, 'page': None, 'target': None},
#   {'title': 'PART II', 'level': 1, 'page': None, 'target': None},
#   {'title': 'PART III', 'level': 1, 'page': None, 'target': None},
#   {'title': 'PART IV', 'level': 1, 'page': None, 'target': None},
#   {'title': 'Exhibit Index', 'level': 1, 'page': 65, 'target': None},
#   {'title': 'SIGNATURES', 'level': 1, 'page': 65, 'target': 'sec_798'}],
#  'views': [{'type': 'page', 'node_id': 'P0', 'page_idx': 0},
#   {'type': 'page', 'node_id': 'P1', 'page_idx': 1},
#   {'type': 'page', 'node_id': 'P2', 'page_idx': 2},
#   {'type': 'page', 'node_id': 'P3', 'page_idx': 3},
#   {'type': 'page', 'node_id': 'P4', 'page_idx': 4},
#   {'type': 'page', 'node_id': 'P5', 'page_idx': 5},
#   {'type': 'page', 'node_id': 'P6', 'page_idx': 6},
#   {'type': 'page', 'node_id': 'P7', 'page_idx': 7},
#   {'type': 'page', 'node_id': 'P8', 'page_idx': 8},
#   {'type': 'page', 'node_id': 'P9', 'page_idx': 9},
#   {'type': 'page', 'node_id': 'P10', 'page_idx': 10},
#   {'type': 'page', 'node_id': 'P11', 'page_idx': 11},
#   {'type': 'page', 'node_id': 'P12', 'page_idx': 12},
#   {'type': 'page', 'node_id': 'P13', 'page_idx': 13},
#   {'type': 'page', 'node_id': 'P14', 'page_idx': 14},
#   {'type': 'page', 'node_id': 'P15', 'page_idx': 15},
#   {'type': 'page', 'node_id': 'P16', 'page_idx': 16},
#   {'type': 'page', 'node_id': 'P17', 'page_idx': 17},
#   {'type': 'page', 'node_id': 'P18', 'page_idx': 18},
#   {'type': 'page', 'node_id': 'P19', 'page_idx': 19},
#   {'type': 'page', 'node_id': 'P20', 'page_idx': 20},
#   {'type': 'page', 'node_id': 'P21', 'page_idx': 21},
#   {'type': 'page', 'node_id': 'P22', 'page_idx': 22},
#   {'type': 'page', 'node_id': 'P23', 'page_idx': 23},
#   {'type': 'page', 'node_id': 'P24', 'page_idx': 24},
#   {'type': 'page', 'node_id': 'P25', 'page_idx': 25},
#   {'type': 'page', 'node_id': 'P26', 'page_idx': 26},
#   {'type': 'page', 'node_id': 'P27', 'page_idx': 27},
#   {'type': 'page', 'node_id': 'P28', 'page_idx': 28},
#   {'type': 'page', 'node_id': 'P29', 'page_idx': 29},
#   {'type': 'page', 'node_id': 'P30', 'page_idx': 30},
#   {'type': 'page', 'node_id': 'P31', 'page_idx': 31},
#   {'type': 'page', 'node_id': 'P32', 'page_idx': 32},
#   {'type': 'page', 'node_id': 'P33', 'page_idx': 33},
#   {'type': 'page', 'node_id': 'P34', 'page_idx': 34},
#   {'type': 'page', 'node_id': 'P35', 'page_idx': 35},
#   {'type': 'page', 'node_id': 'P36', 'page_idx': 36},
#   {'type': 'page', 'node_id': 'P37', 'page_idx': 37},
#   {'type': 'page', 'node_id': 'P38', 'page_idx': 38},
#   {'type': 'page', 'node_id': 'P39', 'page_idx': 39},
#   {'type': 'page', 'node_id': 'P40', 'page_idx': 40},
#   {'type': 'page', 'node_id': 'P41', 'page_idx': 41},
#   {'type': 'page', 'node_id': 'P42', 'page_idx': 42},
#   {'type': 'page', 'node_id': 'P43', 'page_idx': 43},
#   {'type': 'page', 'node_id': 'P44', 'page_idx': 44},
#   {'type': 'page', 'node_id': 'P45', 'page_idx': 45},
#   {'type': 'page', 'node_id': 'P46', 'page_idx': 46},
#   {'type': 'page', 'node_id': 'P47', 'page_idx': 47},
#   {'type': 'page', 'node_id': 'P48', 'page_idx': 48},
#   {'type': 'page', 'node_id': 'P49', 'page_idx': 49},
#   {'type': 'page', 'node_id': 'P50', 'page_idx': 50},
#   {'type': 'page', 'node_id': 'P51', 'page_idx': 51},
#   {'type': 'page', 'node_id': 'P52', 'page_idx': 52},
#   {'type': 'page', 'node_id': 'P53', 'page_idx': 53},
#   {'type': 'page', 'node_id': 'P54', 'page_idx': 54},
#   {'type': 'page', 'node_id': 'P55', 'page_idx': 55},
#   {'type': 'page', 'node_id': 'P56', 'page_idx': 56},
#   {'type': 'page', 'node_id': 'P57', 'page_idx': 57},
#   {'type': 'page', 'node_id': 'P58', 'page_idx': 58},
#   {'type': 'page', 'node_id': 'P59', 'page_idx': 59},
#   {'type': 'page', 'node_id': 'P60', 'page_idx': 60},
#   {'type': 'page', 'node_id': 'P61', 'page_idx': 61},
#   {'type': 'page', 'node_id': 'P62', 'page_idx': 62},
#   {'type': 'page', 'node_id': 'P63', 'page_idx': 63},
#   {'type': 'page', 'node_id': 'P64', 'page_idx': 64},
#   {'type': 'page', 'node_id': 'P65', 'page_idx': 65},
#   {'type': 'page', 'node_id': 'P66', 'page_idx': 66},
#   {'type': 'page', 'node_id': 'P67', 'page_idx': 67},
#   {'type': 'page', 'node_id': 'P68', 'page_idx': 68},
#   {'type': 'page', 'node_id': 'P69', 'page_idx': 69},
#   {'type': 'page', 'node_id': 'P70', 'page_idx': 70},
#   {'type': 'page', 'node_id': 'P71', 'page_idx': 71},
#   {'type': 'page', 'node_id': 'P72', 'page_idx': 72},
#   {'type': 'page', 'node_id': 'P73', 'page_idx': 73},
#   {'type': 'page', 'node_id': 'P74', 'page_idx': 74},
#   {'type': 'page', 'node_id': 'P75', 'page_idx': 75},
#   {'type': 'page', 'node_id': 'P76', 'page_idx': 76},
#   {'type': 'page', 'node_id': 'P77', 'page_idx': 77},
#   {'type': 'page', 'node_id': 'P78', 'page_idx': 78},
#   {'type': 'page', 'node_id': 'P79', 'page_idx': 79},
#   {'type': 'page', 'node_id': 'P80', 'page_idx': 80},
#   {'type': 'page', 'node_id': 'P81', 'page_idx': 81},
#   {'type': 'page', 'node_id': 'P82', 'page_idx': 82},
#   {'type': 'page', 'node_id': 'P83', 'page_idx': 83},
#   {'type': 'page', 'node_id': 'P84', 'page_idx': 84},
#   {'type': 'page', 'node_id': 'P85', 'page_idx': 85},
#   {'type': 'page', 'node_id': 'P86', 'page_idx': 86},
#   {'type': 'page', 'node_id': 'P87', 'page_idx': 87},
#   {'type': 'page', 'node_id': 'P88', 'page_idx': 88},
#   {'type': 'page', 'node_id': 'P89', 'page_idx': 89},
#   {'type': 'page', 'node_id': 'P90', 'page_idx': 90},
#   {'type': 'page', 'node_id': 'P91', 'page_idx': 91},
#   {'type': 'page', 'node_id': 'P92', 'page_idx': 92},
#   {'type': 'page', 'node_id': 'P93', 'page_idx': 93},
#   {'type': 'page', 'node_id': 'P94', 'page_idx': 94},
#   {'type': 'page', 'node_id': 'P95', 'page_idx': 95},
#   {'type': 'page', 'node_id': 'P96', 'page_idx': 96},
#   {'type': 'page', 'node_id': 'P97', 'page_idx': 97},
#   {'type': 'page', 'node_id': 'P98', 'page_idx': 98},
#   {'type': 'page', 'node_id': 'P99', 'page_idx': 99},
#   {'type': 'page', 'node_id': 'P100', 'page_idx': 100},
#   {'type': 'page', 'node_id': 'P101', 'page_idx': 101},
#   {'type': 'page', 'node_id': 'P102', 'page_idx': 102},
#   {'type': 'page', 'node_id': 'P103', 'page_idx': 103},
#   {'type': 'page', 'node_id': 'P104', 'page_idx': 104},
#   {'type': 'page', 'node_id': 'P105', 'page_idx': 105},
#   {'type': 'page', 'node_id': 'P106', 'page_idx': 106},
#   {'type': 'page', 'node_id': 'P107', 'page_idx': 107},
#   {'type': 'page', 'node_id': 'P108', 'page_idx': 108},
#   {'type': 'page', 'node_id': 'P109', 'page_idx': 109},
#   {'type': 'page', 'node_id': 'P110', 'page_idx': 110},
#   {'type': 'page', 'node_id': 'P111', 'page_idx': 111},
#   {'type': 'page', 'node_id': 'P112', 'page_idx': 112},
#   {'type': 'page', 'node_id': 'P113', 'page_idx': 113},
#   {'type': 'page', 'node_id': 'P114', 'page_idx': 114},
#   {'type': 'page', 'node_id': 'P115', 'page_idx': 115},
#   {'type': 'page', 'node_id': 'P116', 'page_idx': 116},
#   {'type': 'page', 'node_id': 'P117', 'page_idx': 117},
#   {'type': 'page', 'node_id': 'P118', 'page_idx': 118},
#   {'type': 'page', 'node_id': 'P119', 'page_idx': 119},
#   {'type': 'page', 'node_id': 'P120', 'page_idx': 120},
#   {'type': 'page', 'node_id': 'P121', 'page_idx': 121},
#   {'type': 'page', 'node_id': 'P122', 'page_idx': 122},
#   {'type': 'page', 'node_id': 'P123', 'page_idx': 123},
#   {'type': 'page', 'node_id': 'P124', 'page_idx': 124},
#   {'type': 'page', 'node_id': 'P125', 'page_idx': 125},
#   {'type': 'page', 'node_id': 'P126', 'page_idx': 126},
#   {'type': 'page', 'node_id': 'P127', 'page_idx': 127},
#   {'type': 'page', 'node_id': 'P128', 'page_idx': 128},
#   {'type': 'page', 'node_id': 'P129', 'page_idx': 129},
#   {'type': 'page', 'node_id': 'P130', 'page_idx': 130},
#   {'type': 'page', 'node_id': 'P131', 'page_idx': 131},
#   {'type': 'page', 'node_id': 'P132', 'page_idx': 132},
#   {'type': 'page', 'node_id': 'P133', 'page_idx': 133},
#   {'type': 'page', 'node_id': 'P134', 'page_idx': 134},
#   {'type': 'page', 'node_id': 'P135', 'page_idx': 135},
#   {'type': 'page', 'node_id': 'P136', 'page_idx': 136},
#   {'type': 'page', 'node_id': 'P137', 'page_idx': 137},
#   {'type': 'page', 'node_id': 'P138', 'page_idx': 138},
#   {'type': 'page', 'node_id': 'P139', 'page_idx': 139},
#   {'type': 'page', 'node_id': 'P140', 'page_idx': 140},
#   {'type': 'page', 'node_id': 'P141', 'page_idx': 141},
#   {'type': 'page', 'node_id': 'P142', 'page_idx': 142},
#   {'type': 'page', 'node_id': 'P143', 'page_idx': 143},
#   {'type': 'page', 'node_id': 'P144', 'page_idx': 144},
#   {'type': 'page', 'node_id': 'P145', 'page_idx': 145},
#   {'type': 'page', 'node_id': 'P146', 'page_idx': 146},
#   {'type': 'page', 'node_id': 'P147', 'page_idx': 147},
#   {'type': 'page', 'node_id': 'P148', 'page_idx': 148},
#   {'type': 'page', 'node_id': 'P149', 'page_idx': 149},
#   {'type': 'page', 'node_id': 'P150', 'page_idx': 150},
#   {'type': 'page', 'node_id': 'P151', 'page_idx': 151},
#   {'type': 'page', 'node_id': 'P152', 'page_idx': 152},
#   {'type': 'page', 'node_id': 'P153', 'page_idx': 153},
#   {'type': 'page', 'node_id': 'P154', 'page_idx': 154},
#   {'type': 'page', 'node_id': 'P155', 'page_idx': 155},
#   {'type': 'page', 'node_id': 'P156', 'page_idx': 156},
#   {'type': 'page', 'node_id': 'P157', 'page_idx': 157},
#   {'type': 'page', 'node_id': 'P158', 'page_idx': 158},
#   {'type': 'page', 'node_id': 'P159', 'page_idx': 159},
#   {'type': 'page', 'node_id': 'P160', 'page_idx': 160},
#   {'type': 'page', 'node_id': 'P161', 'page_idx': 161},
#   {'type': 'page', 'node_id': 'P162', 'page_idx': 162},
#   {'type': 'page', 'node_id': 'P163', 'page_idx': 163},
#   {'type': 'page', 'node_id': 'P164', 'page_idx': 164},
#   {'type': 'page', 'node_id': 'P165', 'page_idx': 165},
#   {'type': 'page', 'node_id': 'P166', 'page_idx': 166},
#   {'type': 'page', 'node_id': 'P167', 'page_idx': 167},
#   {'type': 'page', 'node_id': 'P168', 'page_idx': 168},
#   {'type': 'page', 'node_id': 'P169', 'page_idx': 169},
#   {'type': 'page', 'node_id': 'P170', 'page_idx': 170},
#   {'type': 'page', 'node_id': 'P171', 'page_idx': 171},
#   {'type': 'page', 'node_id': 'P172', 'page_idx': 172},
#   {'type': 'page', 'node_id': 'P173', 'page_idx': 173},
#   {'type': 'page', 'node_id': 'P174', 'page_idx': 174},
#   {'type': 'page', 'node_id': 'P175', 'page_idx': 175},
#   {'type': 'page', 'node_id': 'P176', 'page_idx': 176},
#   {'type': 'page', 'node_id': 'P177', 'page_idx': 177},
#   {'type': 'page', 'node_id': 'P178', 'page_idx': 178},
#   {'type': 'page', 'node_id': 'P179', 'page_idx': 179},
#   {'type': 'page', 'node_id': 'P180', 'page_idx': 180},
#   {'type': 'page', 'node_id': 'P181', 'page_idx': 181},
#   {'type': 'page', 'node_id': 'P182', 'page_idx': 182},
#   {'type': 'page', 'node_id': 'P183', 'page_idx': 183},
#   {'type': 'page', 'node_id': 'P184', 'page_idx': 184},
#   {'type': 'page', 'node_id': 'P185', 'page_idx': 185},
#   {'type': 'page', 'node_id': 'P186', 'page_idx': 186},
#   {'type': 'page', 'node_id': 'P187', 'page_idx': 187},
#   {'type': 'page', 'node_id': 'P188', 'page_idx': 188},
#   {'type': 'page', 'node_id': 'P189', 'page_idx': 189},
#   {'type': 'page', 'node_id': 'P190', 'page_idx': 190},
#   {'type': 'page', 'node_id': 'P191', 'page_idx': 191},
#   {'type': 'page', 'node_id': 'P192', 'page_idx': 192},
#   {'type': 'page', 'node_id': 'P193', 'page_idx': 193},
#   {'type': 'page', 'node_id': 'P194', 'page_idx': 194},
#   {'type': 'page', 'node_id': 'P195', 'page_idx': 195},
#   {'type': 'page', 'node_id': 'P196', 'page_idx': 196},
#   {'type': 'page', 'node_id': 'P197', 'page_idx': 197}],
#  'children': [{'type': 'section',
#    'node_id': 'sec_0',
#    'level': 1,
#    'title': 'UNITED STATES SECURITIES AND EXCHANGE COMMISSION',
#    'title_norm': 'united states securities and exchange commission',
#    'page_idx': 0,
#    'read_order_idx': 0},
#   {'type': 'section',
#    'node_id': 'sec_1',
#    'level': 1,
#    'title': 'Washington, D.C. 20549',
#    'title_norm': 'washington, d.c. 20549',
#    'page_idx': 0,
#    'read_order_idx': 2},
#   {'type': 'section',
#    'node_id': 'sec_2',
#    'level': 1,
#    'title': 'FORM 10-K',
#    'title_norm': 'form 10-k',
#    'page_idx': 0,
#    'read_order_idx': 3,
#    'children': [{'type': 'text',
#      'node_id': 't_3',
#      'page_idx': 0,
#      'read_order_idx': 4,
#      'role': 'paragraph',
#      'text': 'ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934',
#      'bbox': [92.0, 100.0, 524.0, 111.0]},
#     {'type': 'text',
#      'node_id': 't_4',
#      'page_idx': 0,
#      'read_order_idx': 5,
#      'role': 'paragraph',
#      'text': 'For the Fiscal Year Ended December 31, 2019',
#      'bbox': [210.0, 118.0, 378.0, 128.0]},
#     {'type': 'text',
#      'node_id': 't_5',
#      'page_idx': 0,
#      'read_order_idx': 6,
#      'role': 'paragraph',
#      'text': 'OR',
#      'bbox': [289.0, 135.0, 304.0, 143.0]},
#     {'type': 'text',
#      'node_id': 't_6',
#      'page_idx': 0,
#      'read_order_idx': 7,
#      'role': 'paragraph',
#      'text': '□TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934',
#      'bbox': [87.0, 148.0, 529.0, 159.0]},
#     {'type': 'text',
#      'node_id': 't_7',
#      'page_idx': 0,
#      'read_order_idx': 8,
#      'role': 'paragraph',
#      'text': 'For the transition period from to',
#      'bbox': [217.0, 164.0, 384.0, 175.0]},
#     {'type': 'text',
#      'node_id': 't_8',
#      'page_idx': 0,
#      'read_order_idx': 9,
#      'role': 'paragraph',
#      'text': 'Commission File Number 1-15839',
#      'bbox': [234.0, 179.0, 359.0, 190.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_9',
#    'level': 1,
#    'title': 'ACTIVISION. BLZZARD',
#    'title_norm': 'activision. blzzard',
#    'page_idx': 0,
#    'read_order_idx': 10},
#   {'type': 'section',
#    'node_id': 'sec_10',
#    'level': 1,
#    'title': 'ACTIVISION BLIZZARD, INC.',
#    'title_norm': 'activision blizzard, inc.',
#    'page_idx': 0,
#    'read_order_idx': 11,
#    'children': [{'type': 'text',
#      'node_id': 't_11',
#      'page_idx': 0,
#      'read_order_idx': 12,
#      'role': 'paragraph',
#      'text': '(Exact name of registrant as specified in its charter)',
#      'bbox': [207.0, 237.0, 385.0, 247.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_12',
#    'level': 1,
#    'title': 'Delaware',
#    'title_norm': 'delaware',
#    'page_idx': 0,
#    'read_order_idx': 13,
#    'children': [{'type': 'text',
#      'node_id': 't_13',
#      'page_idx': 0,
#      'read_order_idx': 14,
#      'role': 'paragraph',
#      'text': '(State or other jurisdiction of incorporation or organization)',
#      'bbox': [49.0, 267.0, 254.0, 278.0]},
#     {'type': 'text',
#      'node_id': 't_14',
#      'page_idx': 0,
#      'read_order_idx': 15,
#      'role': 'paragraph',
#      'text': '3100 Ocean Park Boulevard',
#      'bbox': [31.0, 280.0, 135.0, 290.0]},
#     {'type': 'text',
#      'node_id': 't_15',
#      'page_idx': 0,
#      'read_order_idx': 16,
#      'role': 'paragraph',
#      'text': 'Santa Monica,',
#      'bbox': [184.0, 280.0, 239.0, 290.0]},
#     {'type': 'text',
#      'node_id': 't_16',
#      'page_idx': 0,
#      'read_order_idx': 17,
#      'role': 'paragraph',
#      'text': '(Address of principal executive offices)',
#      'bbox': [83.0, 293.0, 220.0, 304.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_17',
#    'level': 1,
#    'title': '95-4803544',
#    'title_norm': '95-4803544',
#    'page_idx': 0,
#    'read_order_idx': 18,
#    'children': [{'type': 'text',
#      'node_id': 't_18',
#      'page_idx': 0,
#      'read_order_idx': 19,
#      'role': 'paragraph',
#      'text': '(I.R.S. Employer Identification No.)',
#      'bbox': [382.0, 267.0, 507.0, 278.0]},
#     {'type': 'text',
#      'node_id': 't_19',
#      'page_idx': 0,
#      'read_order_idx': 20,
#      'role': 'paragraph',
#      'text': '90405',
#      'bbox': [433.0, 280.0, 456.0, 290.0]},
#     {'type': 'text',
#      'node_id': 't_20',
#      'page_idx': 0,
#      'read_order_idx': 21,
#      'role': 'paragraph',
#      'text': '(Zip Code)',
#      'bbox': [425.0, 293.0, 464.0, 303.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_21',
#    'level': 1,
#    'title': '(310) 255-2000',
#    'title_norm': '(310) 255-2000',
#    'page_idx': 0,
#    'read_order_idx': 22,
#    'children': [{'type': 'text',
#      'node_id': 't_22',
#      'page_idx': 0,
#      'read_order_idx': 23,
#      'role': 'paragraph',
#      'text': "(Registrar's telephone number, including area code)",
#      'bbox': [205.0, 316.0, 387.0, 326.0]},
#     {'type': 'text',
#      'node_id': 't_23',
#      'page_idx': 0,
#      'read_order_idx': 24,
#      'role': 'paragraph',
#      'text': 'Securities registered pursuant to Section 12(b) of the Act:',
#      'bbox': [9.0, 330.0, 208.0, 341.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_24',
#    'level': 1,
#    'title': 'Title of each class',
#    'title_norm': 'title of each class',
#    'page_idx': 0,
#    'read_order_idx': 25,
#    'children': [{'type': 'text',
#      'node_id': 't_25',
#      'page_idx': 0,
#      'read_order_idx': 26,
#      'role': 'paragraph',
#      'text': 'Common Stock, par value $0.000001 per share',
#      'bbox': [50.0, 362.0, 212.0, 372.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_26',
#    'level': 1,
#    'title': 'Trading Symbol(s)',
#    'title_norm': 'trading symbol(s)',
#    'page_idx': 0,
#    'read_order_idx': 27,
#    'children': [{'type': 'text',
#      'node_id': 't_27',
#      'page_idx': 0,
#      'read_order_idx': 28,
#      'role': 'paragraph',
#      'text': 'ATVI',
#      'bbox': [295.0, 362.0, 316.0, 370.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_28',
#    'level': 1,
#    'title': 'Name of each exchange on which registered',
#    'title_norm': 'name of each exchange on which registered',
#    'page_idx': 0,
#    'read_order_idx': 29,
#    'children': [{'type': 'text',
#      'node_id': 't_29',
#      'page_idx': 0,
#      'read_order_idx': 30,
#      'role': 'paragraph',
#      'text': 'The Nasdaq Global Select Market',
#      'bbox': [411.0, 362.0, 529.0, 371.0]},
#     {'type': 'text',
#      'node_id': 't_30',
#      'page_idx': 0,
#      'read_order_idx': 31,
#      'role': 'paragraph',
#      'text': 'Securities registered pursuant to Section 12(g) of the Act:',
#      'bbox': [197.0, 378.0, 395.0, 389.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_31',
#    'level': 1,
#    'title': 'None',
#    'title_norm': 'none',
#    'page_idx': 0,
#    'read_order_idx': 32,
#    'children': [{'type': 'text',
#      'node_id': 't_32',
#      'page_idx': 0,
#      'read_order_idx': 33,
#      'role': 'paragraph',
#      'text': 'Indicate by check mark if the registrant is a well-known seasoned issuer, as defined in Rule 405 of the Securities Act. Yes No',
#      'bbox': [24.0, 411.0, 474.0, 422.0]},
#     {'type': 'text',
#      'node_id': 't_33',
#      'page_idx': 0,
#      'read_order_idx': 34,
#      'role': 'paragraph',
#      'text': 'Indicate by check mark if the registrant is not required to file reports pursuant to Section 13 or Section 15 (d) of the Act. Yes No',
#      'bbox': [24.0, 428.0, 482.0, 439.0]},
#     {'type': 'text',
#      'node_id': 't_34',
#      'page_idx': 0,
#      'read_order_idx': 35,
#      'role': 'paragraph',
#      'text': 'Indicate by check mark whether the registrant: (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days. Yes No',
#      'bbox': [8.0, 446.0, 583.0, 478.0]},
#     {'type': 'text',
#      'node_id': 't_35',
#      'page_idx': 0,
#      'read_order_idx': 36,
#      'role': 'paragraph',
#      'text': 'Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§ 232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files). Yes ☒ No ☐',
#      'bbox': [8.0, 485.0, 579.0, 507.0]},
#     {'type': 'text',
#      'node_id': 't_36',
#      'page_idx': 0,
#      'read_order_idx': 37,
#      'role': 'paragraph',
#      'text': 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, smaller reporting company, or an emerging growth company. See the definitions of "large accelerated filer", "accelerated filer", "smaller reporting company", and "emerging growth company" in Rule 12b-2 of the Exchange Act.',
#      'bbox': [8.0, 513.0, 575.0, 544.0]},
#     {'type': 'text',
#      'node_id': 't_37',
#      'page_idx': 0,
#      'read_order_idx': 38,
#      'role': 'paragraph',
#      'text': 'Large Accelerated Filero',
#      'bbox': [12.0, 550.0, 111.0, 561.0]},
#     {'type': 'text',
#      'node_id': 't_38',
#      'page_idx': 0,
#      'read_order_idx': 39,
#      'role': 'paragraph',
#      'text': 'Non-accelerated Filmer',
#      'bbox': [122.0, 551.0, 198.0, 561.0]},
#     {'type': 'image',
#      'node_id': 'img_39',
#      'page_idx': 0,
#      'read_order_idx': 40,
#      'image_path': 'images/dcdfea1e3355cdd752d8288d1698a7e80f1b023b51a5528e693fa6ee34f5b488.jpg',
#      'bbox': [207.0, 551.0, 216.0, 560.0]},
#     {'type': 'text',
#      'node_id': 't_40',
#      'page_idx': 0,
#      'read_order_idx': 41,
#      'role': 'paragraph',
#      'text': 'Accelerated Filer',
#      'bbox': [233.0, 551.0, 294.0, 561.0]},
#     {'type': 'image',
#      'node_id': 'img_41',
#      'page_idx': 0,
#      'read_order_idx': 42,
#      'image_path': 'images/fe796f6209309de0e55044e4531bc80d26edf992a2b45ff431bb44f597bab8b0.jpg',
#      'bbox': [302.0, 551.0, 317.0, 561.0]},
#     {'type': 'text',
#      'node_id': 't_42',
#      'page_idx': 0,
#      'read_order_idx': 43,
#      'role': 'paragraph',
#      'text': 'Smaller reporting company',
#      'bbox': [327.0, 551.0, 422.0, 562.0]},
#     {'type': 'image',
#      'node_id': 'img_43',
#      'page_idx': 0,
#      'read_order_idx': 44,
#      'image_path': 'images/0bc5bdbbe4cb3f5106fc902695ae7a293f4f72f53bf84fb621419bb15cd2ab74.jpg',
#      'bbox': [432.0, 551.0, 443.0, 561.0]},
#     {'type': 'text',
#      'node_id': 't_44',
#      'page_idx': 0,
#      'read_order_idx': 45,
#      'role': 'paragraph',
#      'text': 'Emerging growth company',
#      'bbox': [460.0, 551.0, 556.0, 562.0]},
#     {'type': 'image',
#      'node_id': 'img_45',
#      'page_idx': 0,
#      'read_order_idx': 46,
#      'image_path': 'images/e50d3ee11da215da4090495bfd78a89f17e98d2f5284c3303897e72a21fbd444.jpg',
#      'bbox': [569.0, 551.0, 578.0, 561.0]},
#     {'type': 'text',
#      'node_id': 't_46',
#      'page_idx': 0,
#      'read_order_idx': 47,
#      'role': 'paragraph',
#      'text': 'If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.',
#      'bbox': [8.0, 565.0, 560.0, 587.0]},
#     {'type': 'text',
#      'node_id': 't_47',
#      'page_idx': 0,
#      'read_order_idx': 48,
#      'role': 'paragraph',
#      'text': 'Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act). Yes No',
#      'bbox': [24.0, 591.0, 462.0, 602.0]},
#     {'type': 'text',
#      'node_id': 't_48',
#      'page_idx': 0,
#      'read_order_idx': 49,
#      'role': 'paragraph',
#      'text': "The aggregate market value of the registrant's Common Stock held by non-affiliates on June 30, 2019 (based on the closing sale price as reported on the Nasdaq) was $35,743,039,830.",
#      'bbox': [8.0, 611.0, 575.0, 632.0]},
#     {'type': 'text',
#      'node_id': 't_49',
#      'page_idx': 0,
#      'read_order_idx': 50,
#      'role': 'paragraph',
#      'text': "The number of shares of the registrant's Common Stock outstanding at February 20, 2020 was 769,221,524.",
#      'bbox': [24.0, 641.0, 394.0, 652.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_50',
#    'level': 1,
#    'title': 'Documents Incorporated by Reference',
#    'title_norm': 'documents incorporated by reference',
#    'page_idx': 0,
#    'read_order_idx': 51,
#    'children': [{'type': 'text',
#      'node_id': 't_51',
#      'page_idx': 0,
#      'read_order_idx': 52,
#      'role': 'paragraph',
#      'text': "Portions of the registrant's definitive Proxy Statement, to be filed with the Securities and Exchange Commission with respect to the 2020 Annual Meeting of Shareholders which is expected to be held on June 11, 2020, are incorporated by reference into Part III of this Annual Report.",
#      'bbox': [8.0, 674.0, 561.0, 696.0]}]},
#   {'type': 'section',
#    'node_id': 'sec_52',
#    'level': 1,
#    'title': 'ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES',
#    'title_norm': 'activision blizzard, inc. and subsidiaries',
#    'page_idx': 1,
#    'read_order_idx': 53,
#    'children': [{'type': 'table',
#      'node_id': 'tab_54',
#      'page_idx': 1,
#      'read_order_idx': 55,
#      'data': '<table><tr><td></td><td></td><td>Page No.</td></tr><tr><td>PART I.</td><td></td><td>3</td></tr><tr><td></td><td>Cautionary Statement</td><td>3</td></tr><tr><td>Item 1.</td><td>Business</td><td>4</td></tr><tr><td>Item 1A.</td><td>Risk Factors</td><td>10</td></tr><tr><td>Item 1B.</td><td>Unresolved Staff Comments</td><td>27</td></tr><tr><td>Item 2.</td><td>Properties</td><td>27</td></tr><tr><td>Item 3.</td><td>Legal Proceedings</td><td>27</td></tr><tr><td>Item 4.</td><td>Mine Safety Disclosures</td><td>27</td></tr><tr><td>PART II.</td><td></td><td>28</td></tr><tr><td>Item 5.</td><td>Market for Registrant&#x27;s Common Equity, Related Stockholder Matters, and Issuer Purchases of Equity Securities</td><td>28</td></tr><tr><td>Item 6.</td><td>Selected Financial Data</td><td>30</td></tr><tr><td>Item 7.</td><td>Management&#x27;s Discussion and Analysis of Financial Condition and Results of Operations</td><td>31</td></tr><tr><td>Item 7A.</td><td>Quantitative and Qualitative Disclosures about Market Risk</td><td>60</td></tr><tr><td>Item 8.</td><td>Financial Statements and Supplementary Data</td><td>62</td></tr><tr><td>Item 9.</td><td>Changes in and Disagreements with Accountants on Accounting and Financial Disclosure</td><td>62</td></tr><tr><td>Item 9A.</td><td>Controls and Procedures</td><td>62</td></tr><tr><td>Item 9B.</td><td>Other Information</td><td>63</td></tr><tr><td>PART III.</td><td></td><td>64</td></tr><tr><td>Item 10.</td><td>Directors, Executive Officers, and Corporate Governance</td><td>64</td></tr><tr><td>Item 11.</td><td>Executive Compensation</td><td>64</td></tr><tr><td>Item 12.</td><td>Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters</td><td>64</td></tr><tr><td>Item 13.</td><td>Certain Relationships and Related Transactions, and Director Independence</td><td>64</td></tr><tr><td>Item 14.</td><td>Principal Accounting Fees and Services</td><td>64</td></tr><tr><td>PART IV.</td><td></td><td>65</td></tr><tr><td>Item 15.</td><td>Exhibits, Financial Statement Schedules</td><td>65</td></tr><tr><td>Item 16.</td><td>Form 10-K Summary</td><td>65</td></tr><tr><td>Exhibit Index</td><td></td><td>E-1</td></tr><tr><td>SIGNATURES</td><td></td><td>E-5</td></tr></table>',
#      'bbox': [8.0, 99.0, 583.0, 460.0],
#      'children': [{'type': 'text',
#        'node_id': 'cap_54',
#        'role': 'caption',
#        'text': 'Table of Contents',
#        'ref': 'tab_54',
#        'page_idx': 1,
#        'read_order_idx': 55}]},
#     {'type': 'section',
#      'node_id': 'sec_57',
#      'level': 2,
#      'title': 'Item 1. Business',
#      'title_norm': 'item 1. business',
#      'page_idx': 2,
#      'read_order_idx': 57,
#      'children': [{'type': 'section',
#        'node_id': 'sec_58',
#        'level': 3,
#        'title': 'PART I',
#        'title_norm': 'part i',
#        'page_idx': 2,
#        'read_order_idx': 58}]},
#     {'type': 'section',
#      'node_id': 'sec_59',
#      'level': 2,
#      'title': 'CAUTIONARY STATEMENT',
#      'title_norm': 'cautionary statement',
#      'page_idx': 2,
#      'read_order_idx': 59,
#      'children': [{'type': 'text',
#        'node_id': 't_60',
#        'page_idx': 2,
#        'read_order_idx': 60,
#        'role': 'paragraph',
#        'text': 'This Annual Report on Form 10-K contains, or incorporates by reference, certain forward-looking statements within the meaning of the Private Securities Litigation Reform Act of 1995. Such statements consist of any statement other than a recitation of historical facts and include, but are not limited to: (1) projections of revenues, expenses, income or loss, earnings or loss per share, cash flow, or other financial items; (2) statements of our plans and objectives, including those related to releases of products or services and restructuring activities; (3) statements of future financial or operating performance, including the impact of tax items thereon; and (4) statements of assumptions underlying such statements. Activision Blizzard, Inc. generally uses words such as "outlook," "forecast," "will," "could," "should," "would," "to be," "plan," "plans," "believes," "may," "might," "expect," "intends," "anticipates," "estimate," "future," "positioned," "potential," "project," "remain," "scheduled," "set to," "subject to," "upcoming," and other similar expressions to help identify forward-looking statements. Forward-looking statements are subject to business and economic risks, reflect management\'s current expectations, estimates, and projections about our business, and are inherently uncertain and difficult to predict.',
#        'bbox': [11.0, 78.0, 580.0, 169.0]},
#       {'type': 'text',
#        'node_id': 't_61',
#        'page_idx': 2,
#        'read_order_idx': 61,
#        'role': 'paragraph',
#        'text': 'The company cautions that a number of important factors could cause Activision Blizzard, Inc.\'s actual future results and other future circumstances to differ materially from those expressed in any forward-looking statements. Some of the risk factors that could cause our actual results to differ from those stated in forward-looking statements can be found in "Risk Factors" included in Part I, Item 1A of this Annual Report on Form 10-K. The forward-looking statements contained herein are based upon information available to us as of the date of this Annual Report on Form 10-K and we assume no obligation to update any such forward-looking statements. Although these forward-looking statements are believed to be true when made, they may ultimately prove to be incorrect. These statements are not guarantees of our future performance and are subject to risks, uncertainties, and other factors, some of which are beyond our control and may cause actual results to differ materially from current expectations.',
#        'bbox': [11.0, 179.0, 574.0, 251.0]},
#       {'type': 'text',
#        'node_id': 't_62',
#        'page_idx': 2,
#        'read_order_idx': 62,
#        'role': 'paragraph',
#        'text': "Activision Blizzard Inc.'s names, abbreviations thereof, logos, and product and service designators are all either the registered or unregistered trademarks or trade names of Activision Blizzard. All other product or service names are the property of their respective owners. All dollar amounts referred to in, or contemplated by, this Annual Report on Form 10-K refer to U.S. dollars, unless otherwise explicitly stated to the contrary.",
#        'bbox': [11.0, 261.0, 572.0, 291.0]}]},
#     {'type': 'section',
#      'node_id': 'sec_65',
#      'level': 2,
#      'title': 'Item 1A. Risk Factors',
#      'title_norm': 'item 1a. risk factors',
#      'page_idx': 3,
#      'read_order_idx': 65,
#      'children': [{'type': 'text',
#        'node_id': 't_66',
#        'page_idx': 3,
#        'read_order_idx': 65,
#        'role': 'paragraph',
#        'text': 'Item 1. BUSINESS',
#        'bbox': [9.0, 37.0, 81.0, 47.0]},
#       {'type': 'section',
#        'node_id': 'sec_67',
#        'level': 3,
#        'title': 'Overview',
#        'title_norm': 'overview',
#        'page_idx': 3,
#        'read_order_idx': 66,
#        'children': [{'type': 'text',
#          'node_id': 't_68',
#          'page_idx': 3,
#          'read_order_idx': 67,
#          'role': 'paragraph',
#          'text': 'Activision Blizzard, Inc. is a leading global developer and publisher of interactive entertainment content and services. We develop and distribute content and services on video game consoles, personal computers ("PC"s), and mobile devices. We also operate esports leagues and offer digital advertising within our content. The terms "Activision Blizzard," the "Company," "we," "us," and "our" are used to refer collectively to Activision Blizzard, Inc. and its subsidiaries.',
#          'bbox': [8.0, 77.0, 584.0, 111.0]},
#         {'type': 'text',
#          'node_id': 't_69',
#          'page_idx': 3,
#          'read_order_idx': 68,
#          'role': 'paragraph',
#          'text': 'The Company was originally incorporated in California in 1979 and was reincorporated in Delaware in December 1992. In connection with the 2008 business combination by and among the Company (then known as Activision, Inc.), Vivendi S.A, and Vivendi Games, Inc., pursuant to which we acquired Blizzard Entertainment, Inc. ("Blizzard"), we were renamed Activision Blizzard, Inc. On February 23, 2016, we acquired King Digital Entertainment plc, a leading interactive mobile entertainment company ("King"), by purchasing all of its outstanding shares.',
#          'bbox': [8.0, 117.0, 576.0, 159.0]}]},
#       {'type': 'section',
#        'node_id': 'sec_70',
#        'level': 3,
#        'title': 'Our Strategy and Vision',
#        'title_norm': 'our strategy and vision',
#        'page_idx': 3,
#        'read_order_idx': 69,
#        'children': [{'type': 'text',
#          'node_id': 't_71',
#          'page_idx': 3,
#          'read_order_idx': 70,
#          'role': 'paragraph',
#          'text': 'Our objective is to continue to be a worldwide leader in the development, publishing, and distribution of high-quality interactive entertainment content and services, as well as related media, that deliver engaging entertainment experiences on a year-round basis. In pursuit of this objective, we focus on three strategic pillars: expanding audience reach; driving deep consumer engagement; and providing more opportunities for player investment.',
#          'bbox': [8.0, 190.0, 582.0, 222.0]},
#         {'type': 'text',
#          'node_id': 't_72',
#          'page_idx': 3,
#          'read_order_idx': 71,
#          'role': 'paragraph',
#          'text': 'Expanding audience reach. Building on our strong established franchises and creating new franchises through compelling new content is at the core of our business. We endeavor to reach as many consumers as possible either through: (1) the purchase of our content and services; (2) engagement in our free-to-play games, which allow consumers to play games with no up-front cost but provide for player investment through sales of downloadable content or via microtransactions; or (3) engagement in other types of media based on our franchises, such as exports.',
#          'bbox': [8.0, 230.0, 579.0, 273.0]},
#         {'type': 'text',
#          'node_id': 't_73',
#          'page_idx': 3,
#          'read_order_idx': 72,
#          'role': 'paragraph',
#          'text': "Driving deep consumer engagement. Our high-quality entertainment content not only expands our audience reach, but it also drives deep engagement with our franchises. We design our games, as well as related media, to provide a depth of content that keeps consumers engaged for a long period of time following a game's release, delivering more value to our players and additional growth opportunities for our franchises.",
#          'bbox': [8.0, 281.0, 572.0, 313.0]},
#         {'type': 'text',
#          'node_id': 't_74',
#          'page_idx': 3,
#          'read_order_idx': 73,
#          'role': 'paragraph',
#          'text': 'Providing more opportunities for player investment. Increasingly, our consumers are connected to our games online through consoles, PCs, and mobile devices. This allows us to offer additional digital player investment opportunities directly to our consumers on a year-round basis. In addition to purchasing full games or subscriptions, players can invest in certain of our games and franchises by purchasing incremental "in-game" content (including larger downloadable content or smaller content, via microtransactions). These digital revenue streams tend to be more recurring and have relatively higher profit margins. Further, if executed properly, additional player investment can increase engagement as it provides more frequent and incremental content for our players. In addition, we generate revenue through offering advertising within certain of our franchises, and we believe there are opportunities to grow new forms of player investment through esports and consumer products. We are still in the early stages of developing these new revenue streams.',
#          'bbox': [8.0, 322.0, 583.0, 395.0]}]},
#       {'type': 'section',
#        'node_id': 'sec_75',
#        'level': 3,
#        'title': 'Reportable Segments',
#        'title_norm': 'reportable segments',
#        'page_idx': 3,
#        'read_order_idx': 74,
#        'children': [{'type': 'text',
#          'node_id': 't_76',
#          'page_idx': 3,
#          'read_order_idx': 75,
#          'role': 'paragraph',
#          'text': 'Based upon our organizational structure, we conduct our business through three reportable segments as follows:',
#          'bbox': [27.0, 423.0, 412.0, 435.0]},
#         {'type': 'section',
#          'node_id': 'sec_77',
#          'level': 4,
#          'title': '(i) Activision Publishing, Inc.',
#          'title_norm': '(i) activision publishing, inc.',
#          'page_idx': 3,
#          'read_order_idx': 76,
#          'children': [{'type': 'text',
#            'node_id': 't_78',
#            'page_idx': 3,
#            'read_order_idx': 77,
#            'role': 'paragraph',
#            'text': 'Activision Publishing, Inc. ("Activision") is a leading global developer and publisher of interactive software products and entertainment content, particularly for the console platform. Activision primarily delivers content through retail and digital channels, including full-game and in-game sales, as well as by licensing software to third-party or related-party companies that distribute Activision products. Activision develops, markets, and sells products primarily based on our internally developed intellectual properties. Activision also includes the activities of the Call of Duty League, a global professional esports league with city-based teams for Call of Duty®.',
#            'bbox': [8.0, 465.0, 579.0, 518.0]},
#           {'type': 'text',
#            'node_id': 't_81',
#            'page_idx': 4,
#            'read_order_idx': 80,
#            'role': 'paragraph',
#            'text': 'Activision\'s key product franchise is Call of Duty, a first-person action title for the console and PC platforms and, following the October 1, 2019 launch of Call of Duty: Mobile, the mobile platform, including for Google Inc.\'s ("Google") Android and Apple Inc.\'s ("Apple") iOS. Call of Duty has been the number one console franchise globally for 10 of the last 11 years, based on data from The NPD Group, GfK Chart-Track, and GSD, and our internal estimates of upfront console sales. Additionally, Call of Duty: Mobile installs exceeded 150 million, ending the fourth quarter of 2019 in the top-15 grossing games in U.S. app stores per App Annie Intelligence and internal estimates.',
#            'bbox': [8.0, 37.0, 584.0, 89.0]}]},
#         {'type': 'section',
#          'node_id': 'sec_82',
#          'level': 4,
#          'title': '(ii) Blizzard Entertainment, Inc.',
#          'title_norm': '(ii) blizzard entertainment, inc.',
#          'page_idx': 4,
#          'read_order_idx': 81,
#          'children': [{'type': 'text',
#            'node_id': 't_83',
#            'page_idx': 4,
#            'read_order_idx': 82,
#            'role': 'paragraph',
#            'text': 'Blizzard is a leading global developer and publisher of interactive software products and entertainment content, particularly for the PC platform. Blizzard primarily delivers content through retail and digital channels, including subscriptions, full-game, and in-game sales, as well as by licensing software to third-party or related-party companies that distribute Blizzard products. Blizzard also maintains a proprietary online gaming service, Blizzard Battle.net®, which facilitates digital distribution of Blizzard content and selected Activision content, online social connectivity, and the creation of user-generated content. Blizzard also includes the activities of the Overwatch LeagueTM, the first major global professional esports league with city-based teams.',
#            'bbox': [8.0, 117.0, 573.0, 170.0]},
#           {'type': 'text',
#            'node_id': 't_84',
#            'page_idx': 4,
#            'read_order_idx': 83,
#            'role': 'paragraph',
#            'text': "Blizzard's key product franchises include: World of Warcraft®, a subscription-based massive multi-player online role-playing game for the PC platform; Diablo®, an action role-playing franchise for the PC and console platforms; Hearthstone®, an online collectible card franchise for the PC and mobile platforms; and Overwatch® a team-based first-person action title for the PC and console platforms.",
#            'bbox': [8.0, 179.0, 581.0, 211.0]}]},
#         {'type': 'section',
#          'node_id': 'sec_85',
#          'level': 4,
#          'title': '(iii) King Digital Entertainment',
#          'title_norm': '(iii) king digital entertainment',
#          'page_idx': 4,
#          'read_order_idx': 84,
#          'children': [{'type': 'text',
#            'node_id': 't_86',
#            'page_idx': 4,
#            'read_order_idx': 85,
#            'role': 'paragraph',
#            'text': "King is a leading global developer and publisher of interactive entertainment content and services, particularly for the mobile platform, including for Google's Android and Apple's iOS. King also distributes its content and services on the PC platform, primarily via Facebook. King's games are free to play; however, players can acquire in-game items, either with virtual currency or real currency, and we continue to focus on in-game advertising as a growing source of additional revenue.",
#            'bbox': [8.0, 240.0, 571.0, 272.0]},
#           {'type': 'text',
#            'node_id': 't_87',
#            'page_idx': 4,
#            'read_order_idx': 86,
#            'role': 'paragraph',
#            'text': 'King\'s key product franchise is Candy CrushTM, which features "match three" games for the mobile and PC platforms.',
#            'bbox': [27.0, 280.0, 434.0, 292.0]}]}]},
#       {'type': 'section',
#        'node_id': 'sec_88',
#        'level': 3,
#        'title': 'Other',
#        'title_norm': 'other',
#        'page_idx': 4,
#        'read_order_idx': 87,
#        'children': [{'type': 'text',
#          'node_id': 't_89',
#          'page_idx': 4,
#          'read_order_idx': 88,
#          'role': 'paragraph',
#          'text': 'We also engage in other businesses that do not represent reportable segments, including the Activision Blizzard Distribution ("Distribution") business, which consists of operations in Europe that provide warehousing, logistics, and sales distribution services to third-party publishers of interactive entertainment software, our own publishing operations, and manufacturers of interactive entertainment hardware.',
#          'bbox': [8.0, 322.0, 576.0, 354.0]}]},
#       {'type': 'section',
#        'node_id': 'sec_90',
#        'level': 3,
#        'title': 'Products',
#        'title_norm': 'products',
#        'page_idx': 4,
#        'read_order_idx': 89,
#        'children': [{'type': 'text',
#          'node_id': 't_91',
#          'page_idx': 4,
#          'read_order_idx': 90,
#          'role': 'paragraph',
#          'text': 'We develop interactive entertainment content and services, principally for console, PC, and mobile devices, and we market and sell our games through retail and digital distribution channels. Our products span various genres, including first- and third-person action/adventure, role-playing, strategy, and "match three," among others. We primarily offer the following products and services:',
#          'bbox': [8.0, 383.0, 577.0, 414.0]},
#         {'type': 'list',
#          'node_id': 'lst_92',
#          'page_idx': 4,
#          'read_order_idx': 91,
#          'items': [{'text': '- full-games, which typically provide access to main game content, primarily for console or PC;'},
#           {'text': '- downloadable content, which provides players with additional in-game content to purchase following the purchase of a full game;'},
#           {'text': '- microtransactions, which typically provide relatively small pieces of additional in-game content or enhancements to gameplay, generally at relatively low price points; and'},
#           {'text': '- subscriptions for players in our World of Warcraft franchise that provide for continual access to the game content.'}],
#          'sub_type': 'text',
#          'bbox': [39.0, 424.0, 578.0, 475.0]},
#         {'type': 'text',
#          'node_id': 't_93',
#          'page_idx': 4,
#          'read_order_idx': 92,
#          'role': 'paragraph',
#          'text': 'Providing additional opportunities for player investment outside of full-game purchases has allowed us to shift from our historical seasonality to a more consistently recurring and year-round revenue model. In addition, if executed properly, it allows us to increase player engagement with our games and content.',
#          'bbox': [8.0, 485.0, 551.0, 507.0]}]},
#       {'type': 'section',
#        'node_id': 'sec_96',
#        'level': 3,
#        'title': 'Product Development and Support',
#        'title_norm': 'product development and support',
#        'page_idx': 5,
#        'read_order_idx': 95,
#        'children': [{'type': 'text',
#          'node_id': 't_97',
#          'page_idx': 5,
#          'read_order_idx': 96,
#          'role': 'paragraph',
#          'text': 'We focus on developing enduring franchises backed by well-designed, high-quality games with regular content updates. We build interactive entertainment content with the potential for broad reach, sustainable engagement and year-round player investment. It is our experience that enduring franchises then serve as the basis for sequels, prequels, and related new products and content that can be released over an extended period of time. We believe that the development and distribution of products and content based on established franchises enhances predictability of revenues and the probability of high unit volume sales and operating profits. We intend to continue development of content based on our owned franchises in the future.',
#          'bbox': [8.0, 57.0, 582.0, 109.0]},
#         {'type': 'text',
#          'node_id': 't_98',
#          'page_idx': 5,
#          'read_order_idx': 97,
#          'role': 'paragraph',
#          'text': 'We develop and produce our titles using a model in which a group of creative, technical, and production professionals, including designers, producers, programmers, artists, and sound engineers, in coordination with our marketing, finance, analytics, sales, and other professionals, has responsibility for the entire development and production process, including the supervision and coordination of internal and, where appropriate, external resources. We believe this model allows us to deploy the best resources for a given task, by supplementing our internal expertise with top-quality external resources on an as-needed basis.',
#          'bbox': [8.0, 118.0, 574.0, 159.0]},
#         {'type': 'text',
#          'node_id': 't_99',
#          'page_idx': 5,
#          'read_order_idx': 98,
#          'role': 'paragraph',
#          'text': 'While most of the content for our franchises is developed by our internal studios, we periodically engage independent third-party developers to create content on our behalf. From time to time, we also acquire the license rights to publish and/or distribute software products that are, or will be, independently created by third-party developers.',
#          'bbox': [8.0, 169.0, 579.0, 200.0]},
#         {'type': 'text',
#          'node_id': 't_100',
#          'page_idx': 5,
#          'read_order_idx': 99,
#          'role': 'paragraph',
# ...
#     'lst_549',
#     'lst_561',
#     'lst_565',
#     'lst_571',
#     'lst_575',
#     'lst_587',
#     'lst_619',
#     'lst_626',
#     'lst_660',
#     'lst_663',
#     'lst_698',
#     'lst_801',
#     'lst_965',
#     'lst_972',
#     'lst_1013',
#     'lst_1033',
#     'lst_1131',
#     'lst_1197',
#     'lst_1328',
#     'lst_1451',
#     'lst_1456',
#     'lst_1491',
#     'lst_1498',
#     'lst_1499',
#     'lst_1503',
#     'lst_1508',
#     'lst_1551',
#     'lst_1554',
#     'lst_1556',
#     'lst_1561',
#     'lst_1566',
#     'lst_1569',
#     'lst_1573',
#     'lst_1577',
#     'lst_1586',
#     'lst_1590',
#     'lst_1617',
#     'lst_1619',
#     'lst_1625',
#     'lst_1626',
#     'lst_1627',
#     'lst_1662',
#     'lst_1664',
#     'lst_1669',
#     'lst_1678',
#     'lst_1679',
#     'lst_1688',
#     'lst_1697',
#     'lst_1701',
#     'lst_1729',
#     'lst_1732',
#     'lst_1753',
#     'lst_1754',
#     'lst_1755',
#     'lst_1762',
#     'lst_1797',
#     'lst_1803',
#     'lst_1806',
#     'lst_1812',
#     'lst_1813',
#     'lst_1815',
#     'lst_1820',
#     'lst_1826',
#     'lst_1827',
#     'lst_1831',
#     'lst_1832',
#     'lst_1841',
#     'lst_1843',
#     'lst_1852',
#     'lst_1869',
#     'lst_1871',
#     'lst_1873',
#     'lst_1876',
#     'lst_1880',
#     'lst_1883',
#     'lst_1896',
#     'lst_1899',
#     'lst_1903',
#     'lst_1906',
#     'lst_1909',
#     'lst_1914',
#     'lst_1917',
#     'lst_1919',
#     'lst_1923',
#     'lst_1925',
#     'lst_1930',
#     'lst_1932',
#     'lst_1934',
#     'lst_1937',
#     'lst_1979',
#     'lst_1981',
#     'lst_1991',
#     'lst_1992',
#     'lst_1994',
#     'lst_2005',
#     'lst_2017']},
#   'heading_index': {'1': {'united states securities and exchange commission': 'sec_0',
#     'washington, d.c. 20549': 'sec_1',
#     'form 10-k': 'sec_2',
#     'activision. blzzard': 'sec_9',
#     'activision blizzard, inc.': 'sec_10',
#     'delaware': 'sec_12',
#     '95-4803544': 'sec_17',
#     '(310) 255-2000': 'sec_21',
#     'title of each class': 'sec_24',
#     'trading symbol(s)': 'sec_26',
#     'name of each exchange on which registered': 'sec_28',
#     'none': 'sec_31',
#     'documents incorporated by reference': 'sec_50',
#     'activision blizzard, inc. and subsidiaries': 'sec_52',
#     'signatures': 'sec_798',
#     '3 the exhibits listed on the accompanying index to exhibits immediately following the financial statements are filed as part of, or hereby incorporated by reference into, this annual report on form 10-k.': 'sec_804'},
#    '2': {'item 1. business': 'sec_57',
#     'cautionary statement': 'sec_59',
#     'item 1a. risk factors': 'sec_65',
#     'item 1b. unresolved staff comments': 'sec_152',
#     'item 2. properties': 'sec_319',
#     'item 3. legal proceedings': 'sec_325',
#     'item 4. mine safety disclosures': 'sec_328',
#     "item 5. market for registrant's common equity, related stockholder matters, and issuer purchases of equity securities": 'sec_333',
#     'item 6. selected financial data': 'sec_358',
#     "item 7. management's discussion and analysis of financial condition and results of operations": 'sec_363',
#     'item 7a. quantitative and qualitative disclosures about market risk': 'sec_730',
#     'item 8. financial statements and supplementary data': 'sec_756',
#     'item 9. changes in and disagreements with accountants on accounting and financial disclosure': 'sec_766',
#     'item 9a. controls and procedures': 'sec_768',
#     'item 9b. other information': 'sec_781',
#     'item 10. directors, executive officers, and corporate governance': 'sec_786',
#     'item 11. executive compensation': 'sec_788',
#     'item 12. security ownership of certain beneficial owners and management and related stockholder matters': 'sec_790',
#     'item 13. certain relationships and related transactions, and director independence': 'sec_792',
#     'item 14. principal accounting fees and services': 'sec_794',
#     'part iv': 'sec_799',
#     'item 15. exhibits, financial statement schedules': 'sec_800',
#     'item 16. form 10-k summary': 'sec_805'},
#    '3': {'part i': 'sec_58',
#     'overview': 'sec_67',
#     'our strategy and vision': 'sec_70',
#     'reportable segments': 'sec_366',
#     'other': 'sec_88',
#     'products': 'sec_90',
#     'product development and support': 'sec_96',
#     'marketing, sales, and distribution': 'sec_101',
#     'manufacturing': 'sec_108',
#     'significant customers and top franchises': 'sec_111',
#     'competition': 'sec_117',
#     'intellectual property': 'sec_123',
#     'employees': 'sec_142',
#     'additional financial information': 'sec_145',
#     'available information': 'sec_147',
#     'we may be subject to intellectual property claims.': 'sec_209',
#     'changes in tax rates or exposure to additional tax liabilities could negatively impact our business.': 'sec_216',
#     'our debt could adversely affect our business.': 'sec_229',
#     'the insolvency or business failure of any of our business partners could negatively impact us.': 'sec_256',
#     'we are a global company and are subject to the risks and uncertainties of conducting business outside the u.s.': 'sec_258',
#     'fluctuations in currency exchange rates could negatively impact our business.': 'sec_266',
#     'change in government regulations relating to the internet could negatively impact our business.': 'sec_285',
#     'catastrophic events may disrupt our business.': 'sec_307',
#     'significant disruption during our live events may adversely affect our business.': 'sec_309',
#     'large-scale medical emergencies or public health epidemics could adversely effect on our business.': 'sec_311',
#     'if general economic conditions decline, demand for our products could decline.': 'sec_313',
#     'part ii': 'sec_332',
#     'stock performance graph': 'sec_336',
#     '10b5-1 stock trading plans': 'sec_349',
#     'issuer purchase of equity securities': 'sec_353',
#     'business overview': 'sec_364',
#     'business results and highlights': 'sec_380',
#     'financial results': 'sec_381',
#     'content release and event highlights': 'sec_386',
#     'international sales': 'sec_392',
#     'operating metrics': 'sec_394',
#     "management's overview of business trends": 'sec_418',
#     'outlook': 'sec_435',
#     'consolidated net revenues': 'sec_445',
#     'segment net revenues': 'sec_481',
#     'segment income from operations': 'sec_494',
#     'consolidated results': 'sec_512',
#     'pc': 'sec_547',
#     'mobile and ancillary': 'sec_550',
#     'costs and expenses': 'sec_554',
#     'french tax settlement': 'sec_597',
#     'irs closing agreement': 'sec_599',
#     'u.s. tax reform act': 'sec_601',
#     'foreign exchange impact': 'sec_604',
#     'comparison of 2018 to 2017': 'sec_648',
#     'liquidity and capital resources': 'sec_608',
#     'dividends': 'sec_641',
#     'capital expenditures': 'sec_644',
#     'commitments': 'sec_646',
#     'off-balance sheet arrangements': 'sec_650',
#     'critical accounting policies and estimates': 'sec_654',
#     'adoption of accounting standards codification 606: revenue from contracts with customers': 'sec_656',
#     'revenue recognition': 'sec_658',
#     'product sales': 'sec_975',
#     'products with online functionality': 'sec_983',
#     'online hosted software arrangements': 'sec_986',
#     'subscription arrangements': 'sec_989',
#     'software licensing revenues': 'sec_996',
#     'other revenues': 'sec_998',
#     'estimated service period': 'sec_1009',
#     'principal agent considerations': 'sec_1011',
#     'income taxes': 'sec_1043',
#     'software development costs': 'sec_711',
#     'fair value estimates': 'sec_716',
#     'assessment of impairment of goodwill and indefinite-lived intangible assets': 'sec_721',
#     'recently issued accounting pronouncements': 'sec_726',
#     'foreign currency exchange rate risk': 'sec_732',
#     'interest rate risk': 'sec_751',
#     'definition and limitations of disclosure controls and procedures.': 'sec_769',
#     'evaluation of disclosure controls and procedures.': 'sec_771',
#     "management's report on internal control over financial reporting.": 'sec_775',
#     'changes in internal control over financial reporting.': 'sec_779',
#     'part iii': 'sec_785',
#     'opinions on the financial statements and internal control over financial reporting': 'sec_810',
#     'basis for opinions': 'sec_815',
#     'definition and limitations of internal control over financial reporting': 'sec_822',
#     'critical audit matters': 'sec_825',
#     'revenue recognition - determination of service period for the online functionality': 'sec_827',
#     'activision blizzard, inc. and subsidiaries': 'sec_1373',
#     'notes to consolidated financial statements': 'sec_863',
#     'notes to consolidated financial statements (continued)': 'sec_1374',
#     '2. summary of significant accounting policies': 'sec_886',
#     'significant judgment around revenue arrangements with multiple deliverables': 'sec_1002',
#     'allowances for returns and price protection': 'sec_1015',
#     'contract balances': 'sec_1023',
#     'shipping and handling': 'sec_1028',
#     'cost of revenues': 'sec_1030',
#     'advertising expenses': 'sec_1041',
#     'foreign currency translation': 'sec_1049',
#     'earnings (loss) per common share': 'sec_1055',
#     'share-based payments': 'sec_1057',
#     'loss contingencies': 'sec_1062',
#     '3. recently issued accounting pronouncements': 'sec_1068',
#     'cloud computing arrangements': 'sec_1078',
#     'financial instruments - credit losses': 'sec_1084',
#     'simplifying the accounting for income taxes': 'sec_1086',
#     '5. software development and intellectual property licenses': 'sec_1091',
#     '6. property and equipment, net': 'sec_1102',
#     '7. intangible assets, net': 'sec_1110',
#     '8. goodwill': 'sec_1123',
#     '9. other assets and liabilities': 'sec_1127',
#     '10. fair value measurements': 'sec_1129',
#     'foreign currency forward contracts': 'sec_1145',
#     'fair value measurements on a non-recurring basis': 'sec_1156',
#     '11. deferred revenues': 'sec_1164',
#     '12. leases': 'sec_1167',
#     '13. debt': 'sec_1190',
#     '14. accumulated other comprehensive income (loss)': 'sec_1219',
#     '15. operating segments and geographic regions': 'sec_1225',
#     '16. share-based payments': 'sec_1280',
#     '17. restructuring': 'sec_1326',
#     '19. income taxes': 'sec_1349',
#     '21. capital transactions': 'sec_1397',
#     '23. commitments and contingencies': 'sec_1413',
#     'valuation and qualifying accounts': 'sec_1434',
#     'exhibit': 'sec_1455',
#     'exhibit number': 'sec_1454',
#     'signature': 'sec_1461',
#     'power of attorney': 'sec_1466',
#     "description of the registrant's securities registered pursuant to section 12 of the securities exchange act of 1934": 'sec_1472',
#     'activision blizzard, inc. 2014 incentive plan': 'sec_1622',
#     'notice of stock option award': 'sec_1751',
#     'exhibit a': 'sec_1772',
#     'stock option award terms': 'sec_1775',
#     '5. tax withholding.': 'sec_1560',
#     '18. venue and governing law.': 'sec_1581',
#     '20. delivery of notices and other documents.': 'sec_1585',
#     'exhibit b': 'sec_1705',
#     'appendix': 'sec_1706',
#     'additional terms and conditions by country': 'sec_1599',
#     'terms and conditions': 'sec_1712',
#     'notifications': 'sec_1715',
#     'appendix for the united states of america': 'sec_1720',
#     'additional terms and conditions of the activision blizzard, inc.': 'sec_1721',
#     '2014 incentive plan': 'sec_1774',
#     'notice of performance-vesting restricted share unit award': 'sec_1623',
#     'exhibita': 'sec_1631',
#     'activision blizzard, inc.': 'sec_1773',
#     'performance-vesting restricted share unit award terms': 'sec_1634',
#     '19. venue and governing law.': 'sec_1692',
#     '21. delivery of notices and other documents.': 'sec_1696',
#     'a-i': 'sec_1703',
#     'restricted share unit award terms': 'sec_1723',
#     'exhibit c': 'sec_1735',
#     'employment agreement': 'sec_1834',
#     'recital': 'sec_1836',
#     'agreement': 'sec_1838',
#     'consent of independent registered public accounting firm': 'sec_1967',
#     'certification': 'sec_1989',
#     'certification pursuant to 18 u.s.c. section 1350,': 'sec_2014',
#     'as adopted pursuant to section 906 of the sarbanes-oxley act of 2002': 'sec_2015'},
#    '4': {'(i) activision publishing, inc.': 'sec_869',
#     '(ii) blizzard entertainment, inc.': 'sec_872',
#     '(iii) king digital entertainment': 'sec_875',
#     'customers': 'sec_112',
#     'top franchises': 'sec_115',
#     '(i) activision': 'sec_368',
#     '(ii) blizzard': 'sec_370',
#     '(iii) king': 'sec_372',
#     'other': 'sec_882',
#     'destiny franchise': 'sec_884',
#     'in-game net bookings': 'sec_406',
#     'monthly active users': 'sec_409',
#     'interactive entertainment growth, including mobile gaming': 'sec_419',
#     'opportunities to expand franchises outside of games': 'sec_422',
#     'concentration of sales among the most popular franchises': 'sec_425',
#     'recurring revenue business models and seasonality': 'sec_432',
#     'consolidated net revenues': 'sec_450',
#     'change in deferred revenues recognized': 'sec_456',
#     'in-game net revenues': 'sec_461',
#     'foreign exchange impact': 'sec_510',
#     'blizzard': 'sec_500',
#     'king': 'sec_492',
#     'activision': 'sec_495',
#     'net revenues by distribution channel': 'sec_513',
#     'digital online channel net revenues': 'sec_516',
#     'retail channel net revenues': 'sec_521',
#     'americas': 'sec_530',
#     'emea': 'sec_532',
#     'asia pacific': 'sec_537',
#     'console': 'sec_543',
#     'net cash provided by operating activities': 'sec_616',
#     'net cash used in investing activities': 'sec_623',
#     'net cash used in financing activities': 'sec_627',
#     'effect of foreign exchange rate changes': 'sec_630',
#     '1. description of business': 'sec_864',
#     'our segments': 'sec_867',
#     'basis of consolidation and presentation': 'sec_887',
#     'cash and cash equivalents': 'sec_892',
#     'investment securities': 'sec_894',
#     'financial instruments': 'sec_903',
#     'concentration of credit risk': 'sec_910',
#     'inventories and allowances for obsolescence': 'sec_920',
#     'software development costs and intellectual property licenses': 'sec_923',
#     'assets recognized from costs to obtain a contract with a customer': 'sec_934',
#     'long-lived assets': 'sec_936',
#     'leases': 'sec_951',
#     'revenue recognition': 'sec_962',
#     'recently adopted accounting pronouncements': 'sec_1069',
#     'recent accounting pronouncements not yet adopted': 'sec_1075',
#     'credit facilities': 'sec_1191',
#     'unsecured senior notes': 'sec_1195',
#     'interest expense and financing costs': 'sec_1206',
#     'activision blizzard equity incentive plans': 'sec_1281',
#     'fair value valuation assumptions': 'sec_1285',
#     'valuation of stock options': 'sec_1286',
#     'volatility.': 'sec_1293',
#     'risk-free interest rate': 'sec_1295',
#     'dividend yield': 'sec_1297',
#     'accuracy of fair value estimates': 'sec_1305',
#     'rsu activity': 'sec_1312',
#     'repurchase programs': 'sec_1398',
#     'dividends': 'sec_1401',
#     'commitments and obligations': 'sec_1414',
#     'legal proceedings': 'sec_1423',
#     'letters of credit': 'sec_1426',
#     'authorized shares': 'sec_1475',
#     'voting rights': 'sec_1477',
#     'dividend rights': 'sec_1479',
#     'liquidation and other rights': 'sec_1481',
#     'preferred stock': 'sec_1487',
#     'anti-takeover effects of provisions of our certificate of incorporation and bylaws': 'sec_1489',
#     'delaware anti-takeover law': 'sec_1492',
#     '1. definitions.': 'sec_1776',
#     '4. termination of employment.': 'sec_1555',
#     '3. termination of employment.': 'sec_1661',
#     '4. tax withholding.': 'sec_1663',
#     '21. notices.': 'sec_1830',
#     '1. term of employment': 'sec_1840',
#     '2. compensation': 'sec_1842',
#     '3. title; location': 'sec_1861',
#     '4. duties': 'sec_1863',
#     '5. expenses': 'sec_1865',
#     '6. other benefits': 'sec_1868',
#     '7. vacation and paid holidays': 'sec_1870',
#     "8. protection of the employer's interests": 'sec_1872',
#     '10. termination of obligations and severance payments': 'sec_1890',
#     '11. general provisions': 'sec_1926',
#     '12. indemnification': 'sec_1938',
#     '13. notices': 'sec_1940'}}}}

# %%
def show_layer(stats: List[Dict[str, Any]], depth: int, type_filter: Optional[str] = None):
    s = next((x for x in stats if x["depth"] == depth), None)
    if not s:
        print(f"没有 depth={depth} 的层"); return
    print(f"[Layer {depth}] total={s['total']} leaf={s['leaf']} leaf_ratio={s['leaf_ratio']} avg_children={s['avg_children']}")
    # 打印示例
    keys = sorted(s["samples"].keys())
    for tk in keys:
        if type_filter and tk != type_filter:
            continue
        items = s["samples"][tk]
        print(f"  - {tk} (samples={len(items)}):")
        for it in items:
            nid = it.get("node_id","")
            pv = it.get("preview","")
            print(f"      {nid} | {pv}")

# %%
def children_of(node: Dict[str, Any]) -> List[Dict[str, Any]]:
    ch = node.get("children")
    return ch if isinstance(ch, list) else []

def is_leaf(node: Dict[str, Any]) -> bool:
    ch = children_of(node)
    return len(ch) == 0
def type_key(node: Dict[str, Any]) -> str:
    t = str(node.get("type") or "")
    # 细分 text 的角色（paragraph/caption），便于感受不同层的内容
    if t == "text":
        role = str(node.get("role") or "")
        if role:
            return f"text:{role}"
    return t

# %%
def preview_text(node: Dict[str, Any], max_len: int = 80) -> str:
    t = node.get("type")
    if t == "section":
        return str(node.get("title") or "")
    if t == "image":
        # 图片：优先描述，其次路径
        desc = node.get("description") or ""
        if desc:
            return desc[:max_len]
        p = node.get("image_path") or ""
        return f"[image] {os.path.basename(p)}"
    if t == "table":
        data = node.get("data") or ""
        s = str(data)
        return (" ".join(s.split()))[:max_len]
    if t == "list":
        items = node.get("items") or []
        if items and isinstance(items, list):
            first = items[0]
            if isinstance(first, dict):
                return str(first.get("text") or "")[:max_len]
            return str(first)[:max_len]
        return "[list]"
    if t == "equation":
        return (str(node.get("text") or ""))[:max_len]
    if t == "text":
        return (str(node.get("text") or ""))[:max_len]
    return f"[{t}]"

# %%
def build_levels(root: Dict[str, Any], max_depth: Optional[int] = None) -> Dict[int, List[Dict[str, Any]]]:
    levels: Dict[int, List[Dict[str, Any]]] = defaultdict(list)
    def dfs(n: Dict[str, Any], d: int):
        levels[d].append(n)
        if max_depth is not None and d >= max_depth:
            return
        for c in children_of(n):
            dfs(c, d+1)
    dfs(root, 0)
    return dict(levels)
def summarize_levels(levels: Dict[int, List[Dict[str, Any]]], samples_per_type: int = 3) -> List[Dict[str, Any]]:
    out: List[Dict[str, Any]] = []
    max_depth = max(levels.keys()) if levels else -1
    for d in range(0, max_depth+1):
        nodes = levels.get(d, [])
        if not nodes:
            continue
        # 统计
        total = len(nodes)
        leaf_cnt = sum(1 for n in nodes if is_leaf(n))
        leaf_ratio = leaf_cnt / total if total else 0.0
        degs = [len(children_of(n)) for n in nodes]
        avg_deg = (sum(degs) / total) if total else 0.0
        types = [type_key(n) for n in nodes]
        type_dist = Counter(types)
        # 示例
        samples: Dict[str, List[Dict[str, str]]] = defaultdict(list)
        for n in nodes:
            tk = type_key(n)
            if len(samples[tk]) < samples_per_type:
                samples[tk].append({
                    "node_id": str(n.get("node_id") or ""),
                    "type": tk,
                    "preview": preview_text(n, 100),
                })
        out.append({
            "depth": d,
            "total": total,
            "leaf": leaf_cnt,
            "leaf_ratio": round(leaf_ratio, 3),
            "avg_children": round(avg_deg, 3),
            "type_counts": dict(type_dist),
            "samples": dict(samples),
        })
    return out

# %%
def peek_level(lv, depth, *, limit=10, type_filter=None, show_preview=True):
    nodes = lv.get(depth, [])
    if type_filter:
        nodes = [n for n in nodes if type_key(n) == type_filter]
    print(f"[depth {depth}] total={len(nodes)} type={type_filter or 'ALL'}")
    from collections import Counter
    if not type_filter:
        print("type_counts:", Counter(type_key(n) for n in nodes))
    for n in nodes[:limit]:
        nid = n.get("node_id")
        t = type_key(n)
        if show_preview:
            print(f"  - {nid} | {t} | {preview_text(n)}")
        else:
            print(f"  - {nid} | {t}")

# %%
doc_path = "./../../../data/users/yiming/dtagent/MinerU_25_MMLB/ACTIVISIONBLIZZARD_2019_10K/doctree.mm.json"
root = load_doctree(doc_path)
lv = build_levels(root, max_depth=None)
stats = summarize_levels(lv, samples_per_type=3)
# show_layer(stats, levels=1)
peek_level(lv,2)
# Out:
# [depth 2] total=63 type=ALL
# type_counts: Counter({'text:paragraph': 35, 'section': 23, 'image': 4, 'table': 1})
#   - t_3 | text:paragraph | ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF
#   - t_4 | text:paragraph | For the Fiscal Year Ended December 31, 2019
#   - t_5 | text:paragraph | OR
#   - t_6 | text:paragraph | □TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE AC
#   - t_7 | text:paragraph | For the transition period from to
#   - t_8 | text:paragraph | Commission File Number 1-15839
#   - t_11 | text:paragraph | (Exact name of registrant as specified in its charter)
#   - t_13 | text:paragraph | (State or other jurisdiction of incorporation or organization)
#   - t_14 | text:paragraph | 3100 Ocean Park Boulevard
#   - t_15 | text:paragraph | Santa Monica,

# %%
show_layer(stats, depth=3)
# Out:
# [Layer 3] total=319 leaf=135 leaf_ratio=0.423 avg_children=2.661
#   - list (samples=1):
#       lst_801 | (a) 1 Financial Statements See Item 8.—Consolidated Financial Statements and Supplementary Data for
#   - section (samples=3):
#       sec_58 | PART I
#       sec_67 | Overview
#       sec_70 | Our Strategy and Vision
#   - table (samples=1):
#       tab_360 | <table><tr><td rowspan="2"></td><td colspan="5">For the Years Ended December 31,</td></tr><tr><td>20
#   - text:caption (samples=1):
#       cap_54 | Table of Contents
#   - text:paragraph (samples=3):
#       t_60 | This Annual Report on Form 10-K contains, or incorporates by reference, certain forward-looking stat
#       t_61 | The company cautions that a number of important factors could cause Activision Blizzard, Inc.'s actu
#       t_62 | Activision Blizzard Inc.'s names, abbreviations thereof, logos, and product and service designators

# %%
def show_headings_at_level(lv, depth, *, unique=False, show_id=False, show_level=True, limit=None, pattern=None):
    import re
    nodes = [n for n in lv.get(depth, []) if n.get("type") == "section"]
    if pattern:
        rx = re.compile(pattern, re.I)
        nodes = [n for n in nodes if rx.search(str(n.get("title") or ""))]
    # 去重（按 title_norm 优先，退化到 lower(strip)）
    if unique:
        seen = set()
        deduped = []
        for n in nodes:
            key = n.get("title_norm") or str(n.get("title") or "").strip().lower()
            if key in seen: continue
            seen.add(key); deduped.append(n)
        nodes = deduped
    if limit is not None:
        nodes = nodes[:limit]
    print(f"[depth {depth}] headings: {len(nodes)}")
    for n in nodes:
        title = str(n.get("title") or "")
        parts = []
        if show_id: parts.append(str(n.get("node_id") or ""))
        if show_level and n.get("level") is not None: parts.append(f"H{n.get('level')}")
        if n.get("page_idx") is not None: parts.append(f"p{n.get('page_idx')}")
        meta = (" | ".join(parts) + " — ") if parts else ""
        print(f"  - {meta}{title}")

def show_captions_at_level(lv, depth, *, limit=None, pattern=None):
    import re
    nodes = [n for n in lv.get(depth, []) if n.get("type") == "text" and n.get("role") == "caption"]
    if pattern:
        rx = re.compile(pattern, re.I)
        nodes = [n for n in nodes if rx.search(str(n.get("text") or ""))]
    if limit is not None:
        nodes = nodes[:limit]
    print(f"[depth {depth}] captions: {len(nodes)}")
    for n in nodes:
        cap = str(n.get("text") or "")
        nid = str(n.get("node_id") or "")
        pg = f"p{n.get('page_idx')}" if n.get("page_idx") is not None else ""
        print(f"  - {nid} {pg} — {cap[:120]}")

# %%
show_headings_at_level(lv, 3)
# Out:
# [depth 3] headings: 234
#   - H3 | p2 — PART I
#   - H3 | p3 — Overview
#   - H3 | p3 — Our Strategy and Vision
#   - H3 | p3 — Reportable Segments
#   - H3 | p4 — Other
#   - H3 | p4 — Products
#   - H3 | p5 — Product Development and Support
#   - H3 | p5 — Marketing, Sales, and Distribution
#   - H3 | p6 — Manufacturing
#   - H3 | p6 — Significant Customers and Top Franchises
#   - H3 | p6 — Competition
#   - H3 | p7 — Intellectual Property
#   - H3 | p8 — Employees
#   - H3 | p8 — Additional Financial Information
#   - H3 | p8 — Available Information
#   - H3 | p14 — We may be subject to intellectual property claims.
#   - H3 | p15 — Changes in tax rates or exposure to additional tax liabilities could negatively impact our business.
#   - H3 | p16 — Our debt could adversely affect our business.
#   - H3 | p19 — The insolvency or business failure of any of our business partners could negatively impact us.
#   - H3 | p19 — We are a global company and are subject to the risks and uncertainties of conducting business outside the U.S.
#   - H3 | p20 — Fluctuations in currency exchange rates could negatively impact our business.
#   - H3 | p22 — Change in government regulations relating to the Internet could negatively impact our business.
#   - H3 | p25 — Catastrophic events may disrupt our business.
#   - H3 | p25 — Significant disruption during our live events may adversely affect our business.
#   - H3 | p25 — Large-scale medical emergencies or public health epidemics could adversely effect on our business.
#   - H3 | p25 — If general economic conditions decline, demand for our products could decline.
#   - H3 | p27 — PART II
#   - H3 | p27 — Stock Performance Graph
#   - H3 | p28 — 10b5-1 Stock Trading Plans
#   - H3 | p28 — Issuer Purchase of Equity Securities
#   - H3 | p30 — Business Overview
#   - H3 | p30 — Reportable Segments
#   - H3 | p31 — Business Results and Highlights
#   - H3 | p31 — Financial Results
#   - H3 | p31 — Content Release and Event Highlights
#   - H3 | p32 — International Sales
#   - H3 | p32 — Operating Metrics
#   - H3 | p34 — Management's Overview of Business Trends
#   - H3 | p35 — Outlook
#   - H3 | p37 — Consolidated Net Revenues
#   - H3 | p40 — Segment Net Revenues
#   - H3 | p41 — Segment Income from Operations
#   - H3 | p42 — Consolidated Results
#   - H3 | p44 — PC
#   - H3 | p44 — Mobile and Ancillary
#   - H3 | p45 — Costs and Expenses
#   - H3 | p48 — French Tax Settlement
#   - H3 | p48 — IRS Closing Agreement
#   - H3 | p48 — U.S. Tax Reform Act
#   - H3 | p48 — Foreign Exchange Impact
#   - H3 | p48 — Comparison of 2018 to 2017
#   - H3 | p48 — Liquidity and Capital Resources
#   - H3 | p51 — Dividends
#   - H3 | p51 — Capital Expenditures
#   - H3 | p51 — Commitments
#   - H3 | p51 — Comparison of 2018 to 2017
#   - H3 | p51 — Off-balance Sheet Arrangements
#   - H3 | p52 — Critical Accounting Policies and Estimates
#   - H3 | p52 — Adoption of Accounting Standards Codification 606: Revenue from Contracts with Customers
#   - H3 | p52 — Revenue Recognition
#   - H3 | p53 — Product Sales
#   - H3 | p53 — Products with Online Functionality
#   - H3 | p54 — Online Hosted Software Arrangements
#   - H3 | p54 — Subscription Arrangements
#   - H3 | p54 — Software Licensing Revenues
#   - H3 | p54 — Other Revenues
#   - H3 | p55 — Estimated Service Period
#   - H3 | p55 — Principal Agent Considerations
#   - H3 | p56 — Income Taxes
#   - H3 | p57 — Software Development Costs
#   - H3 | p57 — Fair Value Estimates
#   - H3 | p58 — Assessment of Impairment of Goodwill and Indefinite-lived Intangible Assets
#   - H3 | p58 — Recently Issued Accounting Pronouncements
#   - H3 | p59 — Foreign Currency Exchange Rate Risk
#   - H3 | p60 — Interest Rate Risk
#   - H3 | p61 — Definition and Limitations of Disclosure Controls and Procedures.
#   - H3 | p61 — Evaluation of Disclosure Controls and Procedures.
#   - H3 | p62 — Management's Report on Internal Control Over Financial Reporting.
#   - H3 | p62 — Changes in Internal Control Over Financial Reporting.
#   - H3 | p63 — PART III
#   - H3 | p65 — Opinions on the Financial Statements and Internal Control over Financial Reporting
#   - H3 | p65 — Basis for Opinions
#   - H3 | p66 — Definition and Limitations of Internal Control over Financial Reporting
#   - H3 | p66 — Critical Audit Matters
#   - H3 | p66 — Revenue Recognition - Determination of Service Period for the Online Functionality
#   - H3 | p73 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p73 — Notes to Consolidated Financial Statements
#   - H3 | p74 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p74 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p74 — 2. Summary of Significant Accounting Policies
#   - H3 | p75 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p75 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p76 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p76 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p77 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p77 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p78 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p78 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p79 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p79 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p80 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p80 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p80 — Product Sales
#   - H3 | p81 — Products with Online Functionality
#   - H3 | p81 — Online Hosted Software Arrangements
#   - H3 | p81 — Subscription Arrangements
#   - H3 | p82 — Software Licensing Revenues
#   - H3 | p82 — Other Revenues
#   - H3 | p82 — Significant Judgment around Revenue Arrangements with Multiple Deliverables
#   - H3 | p83 — Estimated Service Period
#   - H3 | p83 — Principal Agent Considerations
#   - H3 | p83 — Allowances for Returns and Price Protection
#   - H3 | p84 — Contract Balances
#   - H3 | p84 — Shipping and Handling
#   - H3 | p84 — Cost of Revenues
#   - H3 | p85 — Advertising Expenses
#   - H3 | p85 — Income Taxes
#   - H3 | p85 — Foreign Currency Translation
#   - H3 | p86 — Earnings (Loss) Per Common Share
#   - H3 | p86 — Share-Based Payments
#   - H3 | p86 — Loss Contingencies
#   - H3 | p87 — 3. Recently Issued Accounting Pronouncements
#   - H3 | p87 — Cloud Computing Arrangements
#   - H3 | p88 — Financial Instruments - Credit Losses
#   - H3 | p88 — Simplifying the Accounting for Income Taxes
#   - H3 | p88 — 5. Software Development and Intellectual Property Licenses
#   - H3 | p89 — 6. Property and Equipment, Net
#   - H3 | p90 — 7. Intangible Assets, Net
#   - H3 | p91 — 8. Goodwill
#   - H3 | p91 — 9. Other Assets and Liabilities
#   - H3 | p91 — 10. Fair Value Measurements
#   - H3 | p93 — Foreign Currency Forward Contracts
#   - H3 | p93 — Fair Value Measurements on a Non-Recurring Basis
#   - H3 | p94 — 11. Deferred Revenues
#   - H3 | p94 — 12. Leases
#   - H3 | p96 — 13. Debt
#   - H3 | p98 — 14. Accumulated Other Comprehensive Income (Loss)
#   - H3 | p99 — 15. Operating Segments and Geographic Regions
#   - H3 | p101 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p102 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p102 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p103 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p103 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p104 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p104 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p105 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p105 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p106 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p106 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p107 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p107 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p108 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p108 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p108 — 16. Share-Based Payments
#   - H3 | p110 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p110 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p111 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p111 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p111 — 17. Restructuring
#   - H3 | p113 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p113 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p114 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p114 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p114 — 19. Income Taxes
#   - H3 | p115 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p115 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p116 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p116 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p117 — ACTIVISION BLIZZARD, INC. AND SUBSIDIARIES
#   - H3 | p117 — Notes to Consolidated Financial Statements (continued)
#   - H3 | p119 — 21. Capital Transactions
#   - H3 | p120 — 23. Commitments and Contingencies
#   - H3 | p122 — VALUATION AND QUALIFYING ACCOUNTS
#   - H3 | p124 — Exhibit
#   - H3 | p125 — Exhibit Number
#   - H3 | p125 — Exhibit
#   - H3 | p126 — Exhibit Number
#   - H3 | p126 — Exhibit
#   - H3 | p127 — SIGNATURE
#   - H3 | p127 — POWER OF ATTORNEY
#   - H3 | p128 — DESCRIPTION OF THE REGISTRANT'S SECURITIES REGISTERED PURSUANT TO SECTION 12 OF THE SECURITIES EXCHANGE ACT OF 1934
#   - H3 | p130 — ACTIVISION BLIZZARD, INC. 2014 INCENTIVE PLAN
#   - H3 | p130 — NOTICE OF STOCK OPTION AWARD
#   - H3 | p132 — EXHIBIT A
#   - H3 | p132 — STOCK OPTION AWARD TERMS
#   - H3 | p136 — 5. Tax Withholding.
#   - H3 | p140 — 18. Venue and Governing Law.
#   - H3 | p140 — 20. Delivery of Notices and Other Documents.
#   - H3 | p142 — EXHIBIT B
#   - H3 | p142 — APPENDIX
#   - H3 | p142 — ADDITIONAL TERMS AND CONDITIONS BY COUNTRY
#   - H3 | p142 — TERMS AND CONDITIONS
#   - H3 | p142 — NOTIFICATIONS
#   - H3 | p143 — APPENDIX FOR THE UNITED STATES OF AMERICA
#   - H3 | p143 — ADDITIONAL TERMS AND CONDITIONS OF THE ACTIVISION BLIZZARD, INC.
#   - H3 | p143 — 2014 INCENTIVE PLAN
#   - H3 | p143 — STOCK OPTION AWARD TERMS
#   - H3 | p145 — ACTIVISION BLIZZARD, INC. 2014 INCENTIVE PLAN
#   - H3 | p145 — NOTICE OF PERFORMANCE-VESTING RESTRICTED SHARE UNIT AWARD
#   - H3 | p146 — EXHIBITA
#   - H3 | p146 — ACTIVISION BLIZZARD, INC.
#   - H3 | p146 — 2014 INCENTIVE PLAN
#   - H3 | p146 — PERFORMANCE-VESTING RESTRICTED SHARE UNIT AWARD TERMS
#   - H3 | p153 — 19. Venue and Governing Law.
#   - H3 | p153 — 21. Delivery of Notices and Other Documents.
#   - H3 | p154 — A-I
#   - H3 | p155 — EXHIBIT B
#   - H3 | p155 — APPENDIX
#   - H3 | p155 — TERMS AND CONDITIONS
#   - H3 | p155 — NOTIFICATIONS
#   - H3 | p156 — APPENDIX FOR THE UNITED STATES OF AMERICA
#   - H3 | p156 — ADDITIONAL TERMS AND CONDITIONS OF THE ACTIVISION BLIZZARD, INC.
#   - H3 | p156 — 2014 INCENTIVE PLAN
#   - H3 | p156 — RESTRICTED SHARE UNIT AWARD TERMS
#   - H3 | p158 — EXHIBIT C
#   - H3 | p158 — ACTIVISION BLIZZARD, INC.
#   - H3 | p158 — 2014 INCENTIVE PLAN
#   - H3 | p160 — ACTIVISION BLIZZARD, INC.
#   - H3 | p160 — 2014 INCENTIVE PLAN
#   - H3 | p160 — NOTICE OF STOCK OPTION AWARD
#   - H3 | p162 — EXHIBIT A
#   - H3 | p162 — ACTIVISION BLIZZARD, INC.
#   - H3 | p162 — 2014 INCENTIVE PLAN
#   - H3 | p162 — STOCK OPTION AWARD TERMS
#   - H3 | p171 — EMPLOYMENT AGREEMENT
#   - H3 | p171 — RECITAL
#   - H3 | p171 — AGREEMENT
#   - H3 | p193 — CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM
#   - H3 | p194 — CERTIFICATION
#   - H3 | p195 — CERTIFICATION
#   - H3 | p196 — CERTIFICATION PURSUANT TO 18 U.S.C. SECTION 1350,
#   - H3 | p196 — AS ADOPTED PURSUANT TO SECTION 906 OF THE SARBANES-OXLEY ACT OF 2002
#   - H3 | p197 — CERTIFICATION PURSUANT TO 18 U.S.C. SECTION 1350,
#   - H3 | p197 — AS ADOPTED PURSUANT TO SECTION 906 OF THE SARBANES-OXLEY ACT OF 2002

# %%
from tree.utils_2 import print_heading_outline

# %%
tree = print_heading_outline(root)

# %%
def _media_title(n: dict) -> str:
    """Derive a short label for an image/table node using caption/description/path."""
    t = n.get("type")
    if t == "image":
        caps = n.get("image_caption") if isinstance(n.get("image_caption"), list) else []
        cap = caps[0] if caps else ""
        if cap and isinstance(cap, str):
            return cap
        desc = n.get("description") if isinstance(n.get("description"), str) else ""
        if desc:
            return desc
        p = n.get("img_path") if isinstance(n.get("img_path"), str) else "image"
        import os
        return os.path.basename(p) or "image"
    if t == "table":
        caps = n.get("table_caption") if isinstance(n.get("table_caption"), list) else []
        cap = caps[0] if caps else ""
        if cap and isinstance(cap, str):
            return cap
        return "table"
    return str(n.get("text", ""))

def _shorten_text(text: str, max_len: int = 80) -> str:
    s = (text or "").strip().replace("\n", " ")
    if len(s) <= max_len:
        return s
    return s[: max(0, max_len - 1)].rstrip() + "…"
    
def format_heading_outline(
    flat_root: dict,
    *,
    by_logical_page: bool = False,
    include_meta: bool = True,
    max_len: int = 80,
    include_media: bool = True,
) -> list:
    """
    Build a list of one-line strings representing the heading hierarchy for quick inspection.
    - Indentation reflects node_level (2 spaces per level - 1).
    - Shows node_idx, page/logical_page, level, optional via/frozen flags.
    """
    lines: list = []
    items = list(flat_root.get("children", [])) if isinstance(flat_root, dict) else []
    for n in items:
        t = n.get("type")
        if t not in ("text", "image", "table"):
            continue
        if t in ("image", "table") and not include_media:
            continue
        try:
            lvl = int(n.get("node_level", -1))
        except Exception:
            continue
        if lvl < 1:
            continue
        indent = "  " * max(0, lvl - 1)
        idx = n.get("node_idx")
        lp = n.get("logical_page")
        p = n.get("page_idx")
        # choose label
        label = _media_title(n) if t in ("image", "table") else str(n.get("text", ""))
        text = _shorten_text(label, max_len=max_len)
        meta = n.get("heading_meta") if include_meta and isinstance(n.get("heading_meta"), dict) else None
        flags: list[str] = []
        if meta:
            if meta.get("via"):
                flags.append(str(meta.get("via")))
            if meta.get("frozen"):
                flags.append("frozen")
            if meta.get("inserted"):
                flags.append("inserted")
            if meta.get("corrected_cross_level"):
                flags.append("corrected")
        # media marker
        if t == "image":
            flags.append("image")
        elif t == "table":
            flags.append("table")
        where = f"lp={lp}" if by_logical_page else f"p={p}"
        flag_str = (" [" + ",".join(flags) + "]") if flags else ""
        lines.append(f"{indent}- L{lvl} idx={idx} {where}: {text}{flag_str}")
    return lines

# %%
def print_heading_outline(
    flat_root: dict,
    *,
    by_logical_page: bool = True,
    include_meta: bool = True,
    max_len: int = 80,
    include_media: bool = True,
) -> None:
    """Print heading outline to stdout for quick manual inspection."""
    try:
        lines = format_heading_outline(
            flat_root,
            by_logical_page=by_logical_page,
            include_meta=include_meta,
            max_len=max_len,
            include_media=include_media,
        )
        for ln in lines:
            print(ln)
    except Exception as e:
        print(f"[print_heading_outline] failed: {e}")

# %%
print_heading_outline()
